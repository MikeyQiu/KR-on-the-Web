# %% [markdown]
# Before running the code, several dependant package need to be installed, skip if it already exists.

# %%
pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in /Applications/anaconda3/lib/python3.7/site-packages (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading https://files.pythonhosted.org/packages/0b/04/f62d5834c2bdf90afcaeb23bb5241033c44e27000de64ad8472253daa4a8/pdfminer.six-20200402-py3-none-any.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 5.3MB/s eta 0:00:01
# Requirement already satisfied: chardet; python_version > "3.0" in /Applications/anaconda3/lib/python3.7/site-packages (from pdfminer.six) (3.0.4)
# Requirement already satisfied: pycryptodome in /Applications/anaconda3/lib/python3.7/site-packages (from pdfminer.six) (3.9.7)
# Requirement already satisfied: sortedcontainers in /Applications/anaconda3/lib/python3.7/site-packages (from pdfminer.six) (2.1.0)
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20200402
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /Applications/anaconda3/lib/python3.7/site-packages (0.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-Levenshtein

# %% [markdown]
# Firstly, we make connection with database with pymysql api.

# %%
import pymysql
#https://cloud.tencent.com/developer/article/1395339
import urllib
import pdfminer
import copy
from io import StringIO
from io import BytesIO
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfpage import PDFTextExtractionNotAllowed
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice
from pdfminer.layout import *
from pdfminer.converter import PDFPageAggregator
from urllib.request import Request
from urllib.request import urlopen
import os.path
from pathlib import Path
#input basic info about database
class Processing():
    '''
    This class is used to connect with the mysql database, download the paper and convert to the txt file
    The result return resourceId(string),authorList(List),authorPaper,authorCitation and authorID for further
    processing
    '''
    def __init__(self):
        self.NUM=3
        self.conn=pymysql.connect(host='mysql24.ezhostingserver.com', port=3306, user='krw',password='Y>!V@N_26@]cfJ7(')

    def connection(self):
        '''
        Make connection with given mysql database and excute the given query
        Returns:
            A list containing of the mysql query result
        '''
        query_result=[]
        #cursor is the current point we focus on, which could execute sql command.
        cursor=self.conn.cursor()
        #Here rw is the databse name and training_view is a view for requesting data. The execution should be around 30s.
        cursor.execute("SELECT * FROM krw.training_paper_view group by id desc limit %s;",self.NUM)
        for r in cursor:
            query_result.append(list(r))
        cursor.close()
        return query_result
    
    def pre_processing(self,index,query_result):
        '''
        Handle each sublist in the query list by index
        Args:
            index: int as query_result index
            query_result: List genearted by the connection function
        Returns:
            resourceId: string represents each paper's unique ID, e.g. P12345
            url: string url where pdf file can be obtained
        '''
        resourceId=query_result[index][2]
        authorNum=query_result[index][3]
        url=query_result[index][7]
        webList=["acmweb","aclweb"]
        for web in webList:
            if web in url:
                url=url+".pdf"
        print(resourceId,url)
        return resourceId,url
        
    def query(self,index, resourceId):
        '''
        Extract authors' related information in the query list by index and resouceId
        Args:
            index: int as query_result index
            resourceId: string represents each paper's unique ID, e.g. P12345
        Returns:
            authorList: A list containing strings of all the names of authors
            authorPaper: A dictionary containing integers of all the paper count of authors
            authorCitation: : A dictionary containing integers of all the citation counts of authors
            authorID: A dictionary containing strings of all the strings ID of authors. e.g. A12345
        '''
        temp=[]
        authorList=[]
        #Here krw is the databse name and training_view is a view for requesting data. The execution should be around 30s.
        #conn=pymysql.connect(host='mysql24.ezhostingserver.com', port=3306, user='krw',password='Y>!V@N_26@]cfJ7(')
        cursor=self.conn.cursor()
        #Here krw is the databse name and training_view is a view for requesting data. The execution should be around 30s.
        cursor.execute("SELECT * FROM krw.training_author_view where paper_id=(%s) group by name;",resourceId)
        cursor.close()
        authorPaper={}
        authorCitation={}
        authorID={}
        for r in cursor:
            temp.append(list(r))
        #print(temp)
        for line in temp:
            authorList.append(line[1])
            authorPaper[line[1]]=[line[3]]
            authorCitation[line[1]]=[line[4]]
            authorID[line[1]]=[line[0]]
        #print(authorList)
        return authorList,authorPaper,authorCitation,authorID

    def onlinePdfToTxt(self,dataIo,new_path):
        # Create PDF Parser
        parser = PDFParser(dataIo)
        # Create PDFDocument
        document = PDFDocument(parser)
        # Is it okay for extraction?
        if not document.is_extractable:
            raise PDFTextExtractionNotAllowed
        else:
            # Create PDF Manager
            resmag =PDFResourceManager()
            # Setting parameters
            laparams=LAParams()
            # Createing PDF device
            # device=PDFDevice(resmag )
            device=PDFPageAggregator(resmag ,laparams=laparams)
            # Create PDF explainer
            interpreter=PDFPageInterpreter(resmag ,device)
            # For each page
            for page in PDFPage.create_pages(document):
                interpreter.process_page(page)
                # accept this page's LTP object
                layout=device.get_result()
                for y in layout:
                    try:
                        if(isinstance(y,LTTextBoxHorizontal)):
                            with open('%s'%(new_path),'a',encoding="utf-8") as f:
                                f.write(y.get_text()+'\n')
                                #print("Success！")
                    except:
                        print("Failed")
                        
    def main(self,index):
        '''
        Main function of the class, generate related datastructure for further usage.
        Args:
            index: int as query_result's index
           
        Returns:
            resourceId: string represents each paper's unique ID, e.g. P12345
            authorList: A list containing strings of all the names of authors
            authorPaper: A dictionary containing integers of all the paper count of authors
            authorCitation: : A dictionary containing integers of all the citation counts of authors
            authorID: A dictionary containing strings of all the strings ID of authors. e.g. A12345
        '''
        query_result=self.connection()
#         for index in range(len(NUM)):
        resourceId,url=self.pre_processing(index,query_result)
        try:
            my_file=("txt/%s.txt")%resourceId
            my_file=Path(my_file)
            my_abs_path = my_file.resolve()
        except IOError:
            print("File is not accessible.Download from the url")
            html = urllib.request.urlopen(urllib.request.Request(url)).read()
            dataIo = BytesIO(html)
            self.onlinePdfToTxt(dataIo,'txt/'+str(resourceId)+'.txt')
        authorList,authorPaper,authorCitation,authorID=self.query(index,resourceId)
        return resourceId,authorList,authorPaper,authorCitation,authorID

processing=Processing()
processing.NUM=5
resourceId,authorList,authorPaper,authorCitation,authorID=processing.main(4)
print(authorList)
# Out:
# P1296885 http://arxiv.org/pdf/1703.08840v2.pdf
# ['Jiaming Song', 'Stefano Ermon', 'Yunzhu Li']

# %% [markdown]
# After excution we obtained a 2-dimensional matrix with each row represents a paper. Next, we constract a url based on arXiv id.

# %%
import spacy
import re
import copy
from spacy import displacy
from collections import Counter
import en_core_web_sm
from Levenshtein import *
#nlp = en_core_web_sm.load()
class AuthorInfoExtract():
    '''
    This class is used to extract special author with annotations
    The result is orgnized as a list containing dictionaries
    '''
    STARS=["*",'∗']
    CROSS=["†","‡"]
    def detectCapitalUse(self, word: str) -> bool:
        '''
        Function used to judge author name's capital letters 
        '''
        is_upper = [c.isupper() for c in word]          # Upper 
        is_lower = [c.islower() for c in word]          # Lower             

        if any(is_upper):                               # Upper and lower
            return is_upper[0] and all(is_lower[1:])    # Only first is upper 
        
    def locateContext(self,resourceId):
        '''
        Locate where the authors' information at.
        Args:
            resourceId: string represents each paper's unique ID, e.g. P12345
        Returns:
            output: string containing the related information
        '''
        file = open('txt/'+str(resourceId)+'.txt',encoding="utf-8")
        strings=file.read()
        symbolList=["Abstract",'Abstract.','ABSTRACT','ABSTRACT.'] # different version
        for symbol in symbolList:
            if strings.find(symbol):
                output=strings[0:strings.find(symbol)]
                break
            else:
                print(symbol+" not found!")
                output=strings[0:3000]
        file.close()
        output=output.replace('\n', ' . ').replace('\r', ' ')
        output=output.split(" ")
        return (output)
    
    def acknowledgementJudgement(self,resourceId,authorList,corre):
        '''
        Judge the acknowlegement section whether containing corresponding author's information
        Args:
            resourceId: string represents each paper's unique ID, e.g. P12345
            authorList: A list containing strings of all the names of authors
            corres: A List containing the corresponding author's information e.g. [0,0,1,0]
        Returns:
            corres: A List containing the corresponding author's information after processing  
            e.g. [0,0,1,1]
        '''
        file = open('txt/'+str(resourceId)+'.txt',encoding="utf-8")
        strings=file.read()
        symbolList=["Acknowledgement",'ACKNOWLEDGEMENT','Acknowledgements','ACKNOWLEDGEMENTS','ACK']
        for symbol in symbolList:
            #if name in strings:
            if strings.find(symbol):
                output=strings[strings.find(symbol):strings.find(symbol)+1000]
                break
            else:
                print(symbol+" not found!")
        file.close()
        output=output.replace('\n', ' . ').replace('\r', ' ')
        output=output.split(" ")
        output=" ".join(output)
        if output.find("corresponding"):
            pos= output.find("corresponding")
            print(pos)
            #judge whether there is any name in the author list in the context
            for author in authorList:
                if author in strings[pos-30:pos+30]:
                    corre.append(author)
        return corre
    def author_contribution(self,resourceId):
        file = open('txt/'+str(resourceId)+'.txt',encoding="utf-8")
        strings=file.read()
        symbolList=["Author Contributions","Author Contribution"]
        for symbol in symbolList:
            res=bool(re.search(symbol, strings, re.IGNORECASE))
            if res==True:
                return True
            else:
                continue
        return False
            
    def symbolJudgement(self,resourceId):
        '''
        Judge symbol represent what in the context.
        Args:
            resourceId: string represents each paper's unique ID, e.g. P12345
        Returns:
            num: integer, represent different situations
            0:default
            1:star represent equall 
            2:star represent correspinding 
            3:order ranged by alphabetical order
        '''
        file = open('txt/'+str(resourceId)+'.txt',encoding="utf-8")
        strings=file.read()
        strings=strings[:3000]
        #print(strings)
        if strings.find("equally"):
            pos= strings.find("equally")
            #print(pos)
            for star in self.STARS:
                if star in strings[pos-50:pos+50]:
                    return 1 #star represent equall 
        if strings.find("Corresponding"):
            pos= strings.find("Corresponding")
            for star in self.STARS:
                if star in strings[pos-50:pos+50]:
                    return 2 #star represent correspinding 
        if "Alphabetical" in strings:
            return 3
        return 0
    
    def matchAuthor(self,roleList,authorList):
        '''
        Judge whether author names recognized in the context are the same with author names from mysql
        Args:
            roleList: A list containing author names recognized from the context
            authorList: A list containing strings of all the names of authors
        Returns:
            author_role: A list containing names represent for speical authors
        '''
        author_role=[]
        for role in roleList:
            highest=0
            index=0
            for i in range(len(authorList)):
                if jaro(role, authorList[i])>highest:
                    index=i
                    highest=jaro(role, authorList[i])
            #print(highest,authorList[index])
            if highest>0.7:
                author_role.append(authorList[index])
        return author_role
    
    def specialAuthors(self,output,authorList,resourceId):
        '''
        Determine special authors
        Args:
            output: string containing the related information
            authorList: A list containing strings of all the names of authors
            resourceId: string represents each paper's unique ID, e.g. P12345
        Returns:
            star:A list of name represent for first authors
            corre:A list of names represent for corresponding author
        '''
        starList=[]
        crossList=[]
        for i in range(len(output)):
            for star in self.STARS:
                if star in output[i]:
                    starList.append(" ".join(output[i-2:i+1]))
            for cross in self.CROSS:
                if cross in output[i]:
                    crossList.append(" ".join(output[i-2:i+1]))
        judge=self.symbolJudgement(resourceId)
        #print(judge)
        if judge==0 or judge==1:
            star=self.matchAuthor(starList,authorList)
            corre=self.matchAuthor(crossList,authorList) 
        elif judge==2:
            star=self.matchAuthor(starList,authorList)
            corre=copy.copy(star)
            star=[]
        elif judge==3:
            star=[]
            corre=[]
        #print(star)
        return star,corre

    def sequenceExtratcor(self,output,authorList,parameter=0):
        '''
        Extract the sequence from the author list
        Args:
            output: string containing the related information
            authorList: A list containing strings of all the names of authors
            parameter: 0 represents return the result while 1 represents return original authorList
        Returns:
            author_sequence: A dictionary containing the order of authors, e.g. {AAA:1}
        '''
        author_sequence={}
        author_sequence_list=[]
        authorListCopy=copy.copy(authorList)
        num=1
        for i in range(len(output)):
            for name in authorListCopy:
                if output[i] in name and len(output[i])>=2 and self.detectCapitalUse(output[i]): #Detect capital
                    author_sequence[name]=num
                    author_sequence_list.append(name)
                    num+=1
                    authorListCopy.remove(name)
                    break
        if len(author_sequence_list)==len(authorList):
            authorList=author_sequence_list
        if parameter==0:
            return author_sequence
        else:
            return authorList
    
    def main(self,resourceId,authorList,authorPaper,authorCitation,authorID):
        '''
        main function of class AuthorInfoExtract
        return:
            A dataframe containing all the information extracted
        '''
        extractor=AuthorInfoExtract()
        
        output=extractor.locateContext(resourceId)
        #print(output)
        author_sequence=extractor.sequenceExtratcor(output,authorList)
        print(author_sequence)
        star,corre=extractor.specialAuthors(output,authorList,resourceId)
        output2=extractor.acknowledgementJudgement(resourceId,authorList,corre)
       # print(output2)
        #print(star)
#         try:
        df=pd.DataFrame.from_dict(author_sequence,orient='index',columns=['sequence'])
        df=df.reset_index().rename(columns={'index':'name'})
        df['star']=0
        for index, row in df.iterrows():
            for author in star:
                if row["name"]==author:
                    df.loc[index,"star"] = 1
        df['corre']=0
        for index, row in df.iterrows():
            for author in corre:
                #print(row["name"],author,index)
                if row["name"]==author:
                    df.loc[index,"corre"] = 1
        df['paperCount']=0
        for index, row in df.iterrows():
            for k,v in authorPaper.items():
                #print(row["name"],author,index)
                if row["name"]==k:
                    df.loc[index,"paperCount"] = v

        df['citationCount']=0
        for index, row in df.iterrows():
            for k,v in authorCitation.items():
                #print(row["name"],author,index)
                if row["name"]==k:
                    df.loc[index,"citationCount"] = v
        df['authorID']=0
        for index, row in df.iterrows():
            for k,v in authorID.items():
                #print(row["name"],author,index)
                if row["name"]==k:
                    df.loc[index,"authorID"] = v
#         except:
#             print("error occured!")
#             df=pd.DataFrame(columns=['name', 'sequence', 'star', 'corre'])
        return df
    
# extractor=AuthorInfoExtract()
# annotation=extractor.main()
# annotation

# %%
def lookup_id(author,df):
    '''
    Given dataframe and name return the author ID for triple
    Args:
        author:string of author name
        df:A dataframe generated by the class AuthorInfoExtract 
    Returns:
        authorID: A string represent unique Id of author. e.g. A12345
    '''
    author_id=""
    for index, row in df.iterrows():
        if author==row["name"]:
            author_id=(df.at[index,"authorID"])
            break
    return author_id

def lookup_order(author,df):
    '''
    Given dataframe and name return the author ID for triple
    Args:
        author:string of author name
        df:A dataframe generated by the class AuthorInfoExtract 
    Returns:
        authorID: A string represent unique Id of author. e.g. A12345
    '''
    author_id=""
    for index, row in df.iterrows():
        if author==row["name"]:
            author_order=(df.at[index,"sequence"])
            break
    return int(author_order)
def roleGenerator(df,resourceId):
    '''
    Given dataframe and resourceId to determine the role of each author
    Args:
        df:A dataframe generated by the class AuthorInfoExtract 
        resourceId: string represents each paper's unique ID, e.g. P12345 Used for naming the contribution
    Returns:
        result_1:A list containing dictionary of author_contribution information. e.g.[{AAA:resource}]
        result_2:A list containing dictionary of paper_contribution information.
        result_3:A list containing dictionary of contribution_role information.
    '''
    ROLES=['Writing_Draft','Writing_Review_Editing','Supervision','Resource','Software']
    LEVELS=[10,50,100,200,1000,3000,5000,10000]
    df_role = pd.DataFrame(0.0, index=df.name, columns=ROLES)
    #sieve1:Sequence
    for index in range(len(df)):
        df_role.loc[df.name[index],"Writing_Draft"] =1/df.sequence[index]
        df_role.loc[df.name[index],"Writing_Review_Editing"] =(df.sequence[index]/len(df.sequence))-0.1
    #Last author is likely to be supervisor
    
    #sieve2:Annotation
    for index in range(len(df)):
        if df.star[index]==1:
            df_role.loc[df.name[index],"Writing_Draft"] +=1
        if (len(df.star[df.star>0]))<=2:
            if df.corre[index]==1:
                df_role.loc[df.name[index],"Writing_Review_Editing"] +=1
                df_role.loc[df.name[index],"Supervision"] +=0.5
            
    #sieve3:Citation and Paper
    for index in range(len(df)):
        df_role.Supervision[index]=df.citationCount[index]*0.2/sum(df.citationCount)+df.paperCount[index]*0.8/sum(df.paperCount)
#         print(v)
    for index in range(len(df)):
        num=0.0
        for level in LEVELS:
            if df.citationCount[index]>level:
                num+=0.125
            if df.paperCount[index]>level:
                num+=0.125
        df_role.Resource[index]=num
        df_role.Writing_Review_Editing[index]+=num/5
    print(df_role) 
    author_contribution={}
    paper_contribution={}
    contribution_role={}
    result=[]
    result_1=[]
    result_2=[]
    result_3=[]
#     try:
    if len(df_role.Supervision)>0:
        supervisionMax=max(df_role.Supervision)
    for index in range(len(df_role)):
        try:
            author_id=lookup_id(df.name[index],df)
            author_order=lookup_order(df.name[index],df)
            print(author_id)
            flag=False
            if df_role.loc[df.name[index],"Writing_Draft"]>=1:
                contribution_id=resourceId+"_"+author_id+"_Writing_Draft"
                role="Writing_Draft"
                result.append([contribution_id,resourceId,author_id,role,author_order])
                flag=True
#                 author_contribution[contribution_id] =author_id     #isContributionByAuthor
#                 paper_contribution[resourceId]=contribution_id    #isContributionToPaper
#                 contribution_role[contribution_id]="Writing_Draft"
            if df_role.loc[df.name[index],"Writing_Review_Editing"]>=1:
                contribution_id=resourceId+"_"+author_id+"_Writing_Review_Editing"
#                 author_contribution[contribution_id] =author_id     #isContributionByAuthor
#                 paper_contribution[resourceId]=contribution_id    #isContributionToPaper
#                 contribution_role[contribution_id]="Writing_Review_Editing"
                role="Writing_Review_Editing"
                result.append([contribution_id,resourceId,author_id,role,author_order])
                flag=True
            if df_role.loc[df.name[index],"Resource"]>=1:
                contribution_id=resourceId+"_"+author_id+"_Resource"
#                 author_contribution[contribution_id] =author_id     #isContributionByAuthor
#                 paper_contribution[resourceId]=contribution_id    #isContributionToPaper
#                 contribution_role[contribution_id]="Resource"
                role="Resource"
                result.append([contribution_id,resourceId,author_id,role,author_order])
                flag=True
            if df_role.loc[df.name[index],"Supervision"]==supervisionMax:
                contribution_id=resourceId+"_"+author_id+"_Supervision"
#                 author_contribution[contribution_id] =author_id     #isContributionByAuthor
#                 paper_contribution[resourceId]=contribution_id    #isContributionToPaper
#                 contribution_role[contribution_id]="Supervision"
                role="Supervision"
                result.append([contribution_id,resourceId,author_id,role,author_order])
                flag=True
#             if contribution_id!=None:
#                 print(contribution_id)
#                 result.append([contribution_id,resourceId,author_id,role])
#                 result_1.append(author_contribution)
#                 result_2.append(paper_contribution)
#                 result_3.append(contribution_role)
            if flag==False:
                contribution_id=resourceId+"_"+author_id+"_default"
                role="default"
                result.append([contribution_id,resourceId,author_id,role,author_order])
        except:
            print("fail to generate role")
#     return result_1,result_2,result_3
    return result

#roleGenerator(annotation)

# %%
from Levenshtein import *
import re
class EmailInfoExtract():
    '''
    This class is used to extract email address and match with the authors
    The result is orgnized as a list containing dictionaries
    '''
    def __init__(self):
        self.name_email={}
        self.result=[]
    def get_alpha_str(self,s):
        result = ''.join([x for x in s if x.isalpha()])
        return result

    def email_extraction(self,file_name):
        file = open('txt/'+str(file_name)+'.txt',encoding="utf-8")
        strings=file.read()
        #First page's txt
        strings=strings[:3000]
        matches = []
        matchesGroup=[]
        #1. singular email address
        emailRegex = re.compile(r'''(
            [a-zA-Z0-9._%+-]+      # username
            @+                     # @ symbol

           [a-zA-Z0-9_-]+
           (\.[a-zA-Z0-9_-]+)+
            )''', re.VERBOSE)
        # using RE to match all the patterns in the txt
        for groups in emailRegex.findall(strings):
            matches.append(groups[0])

        list2 = matches
        list_nums = len(list2)
        emailList=[]
        for line in range(list_nums):
            emailList.append(list2[line])
        #2. grouped email list {}
        emailRegex2 = re.compile(r'''(
        \{(.+?)\}+
        @                      # @ symbol

        [a-zA-Z0-9.-]+        # domain name

        (\.[a-zA-Z]{1,4}){1,2} # dot-something
        )''', re.VERBOSE)
        for groups in emailRegex2.findall(strings):
            #print(groups)
            matchesGroup.append(groups[0])
        list3 = matchesGroup
        if len(matchesGroup)>0:
            for gp in list3:
                stringGroup = gp
                index=stringGroup.find("@", 0)
                prefix=stringGroup[:index]
                suffix=stringGroup[index:]
                tempNameList=prefix[1:-1].split(",");
                for name in tempNameList:
                    emailList.append(name+suffix)
                #print(emailList)
        #3. convert to sequenced list if possible 
        sequencedList=[]
        temp_dict={}
        for mail in emailList:
            index=mail.find("@",0)
            prefix=mail[:index]
            email_index=strings.find(prefix)
            temp_dict[mail]=email_index
        sort_idct=sorted(temp_dict.items(),key = lambda x:x[1],reverse = False)
        for k,v in sort_idct:
            sequencedList.append(k)
        #print((sequencedList))

        if len(sequencedList)==len(emailList):
            return sequencedList
        else:
            return emailList
    def lookup_id(self,author,df):
        author_id=""
    #     for index, row in df.iterrows():
        for index, row in df.iterrows():
            #print(index)
            #print(k1,v2)
            if author==row["name"]:
                author_id=(df.at[index,"authorID"])
                break
        return (author_id)

    def order_matching(self,nameList, emailList):   
        print("ORDER MATCHING")
        for i in range(len(nameList)):
            pat = re.compile(''+'(.*?)'+'@', re.S)
            email = pat.findall(emailList[i])
            email=self.get_alpha_str(email)
            name=nameList[i]
            if (jaro(name, str(email)))<0.4:
                return False
            else:
                self.name_email[name]=email
        return self.name_email

    #2.No macthes, need to group based on experience and naive approach
    def naive_matching(self,nameList, emailList):
        print("NAIVE MATCHING")
        for name in nameList:
            highest=0
            index=0
            for i in range(len(emailList)):
                #name=filter(lambda x: x.isalpha(), name)
                #using re to extract the first part of email
                pat = re.compile(''+'(.*?)'+'@', re.S)
                email = pat.findall(emailList[i])
                email=self.get_alpha_str(email)
                #print(str(email))
                #print(jaro(name, str(email)))
                #using jaro to calculate the similarity between two strings
                if jaro(name, str(email))>highest:
                    index=i
                    highest=jaro(name, str(email))
            #set pair with the highest score
                    #print(name,highest,emailList[i])
            #self.name_email[name]=emailList[index]
            #If very sure, remove it from the list to reduce the uncertainty for other pairs
            if highest>=0.6:
                self.name_email[name]=emailList[index]
                emailList.remove(emailList[index])
            if highest<=0.4:
                self.name_email[name]=''
        for email in emailList:
            if email not in self.name_email:
                for name in self.name_email:
                    if self.name_email[name]=='':
                        self.name_email[name]=email
                        #print(jaro(name, str(email)))
        return self.name_email
    
    def main(self,resourceId,authorList,df):
        extractor=AuthorInfoExtract()
        output=extractor.locateContext(resourceId)
        nameList=extractor.sequenceExtratcor(output,authorList,1)
        emailList=self.email_extraction(resourceId)
        #print(emailList)
        if len(emailList)==0:
            return
        name_email={}
        #1.If sequenced list and length matches
        if len(nameList)==len(emailList):
            self.name_email=self.order_matching(nameList, emailList)
        if not name_email:
            self.name_email={}
            self.name_email=self.naive_matching(nameList, emailList)
        
        for k,v in self.name_email.items():
            author_id=self.lookup_id(k,df)
            #print(author_id)
            temp={}
            temp[author_id]=v
            self.result.append(temp)
        return self.result
        #return self.name_email
    
# emailExtractor=EmailInfoExtract()
# name_email=emailExtractor.main()

# name_email

# %%
from rdflib import Graph, ConjunctiveGraph, Literal, BNode, Namespace, RDF, URIRef,RDFS
from rdflib.namespace import DC, FOAF
from owlrl import DeductiveClosure, RDFS_Semantics
import pprint
import json
def create_triple_email(totalList):
    '''
    Create triple and serialize it from the list we generated by the end.
    args:
        totalList: A list contraining sublists, which have dictionaries of author_id:email 
        e.g. [[{A123:aaa@email.com},{...},[{A345:bbb@email.com}]]
    return:
        serialized file, saved as txt
    '''
    g = Graph()
    email_address=URIRef("http://scoaring.com/authorcontributions#emailAddress")
    for lst in totalList:
        if lst!=None:
            for dic in lst:
                for author_id,v1 in dic.items():  
                    author = URIRef("http://www.scoaring.com/ontology#%s")%author_id
                    g.add((author,email_address, Literal(v1)))
    print(len(g))
    print(g.serialize(format='turtle').decode())
    g.serialize(destination='email_final.ttl', format='turtle')
    
# def create_triple_role(totalList,num):
#     '''
#     Create triple and serialize it from the list of role we generated by the end.
#     args:
#         totalList: A list contraining sublists, which have dictionaries of author_id:role 
#         e.g. [[{A123:Resource},{...},[{A345:Supervision}]]
#         num:1 represents Contribution_Author
#             2 represents Paper_Contribution
#             3 represents Contribution_role
#     return:
#         serialized file, saved as txt
#     '''
#     n = Namespace("http://www.scoaring.com/ontology")
#     g = Graph()
#     for lst in totalList:
#         if lst!=None:
#             for dic in lst:
#                 if num==1: #Contribution_Author
#                     for contribution_id,author_id in dic.items():
#                         #contribution = BNode()
#                         contribution = URIRef("http://www.scoaring.com/ontology#%s")%contribution_id
#                         typeClass=URIRef("http://www.scoaring.com/ontology#contribution")
#                         predict= URIRef("http://www.scoaring.com/ontology#isContributionByAuthor")#refersTo
#                         author = URIRef("http://www.scoaring.com/ontology#%s")%author_id
#                         g.add((contribution, RDF.type, typeClass))
#                         g.add((contribution, predict, author))
#                 if num==2: #Paper_Contribution
#                     for paper_id,contribution_id in dic.items():
#                         paper = URIRef("http://www.scoaring.com/ontology#%s")%paper_id
#                         contribution = URIRef("http://www.scoaring.com/ontology#%s")%contribution_id
#                         predict= URIRef("http://www.scoaring.com/ontology#isContributionToPaper")#refersTo
#                         g.add((paper, predict, contribution))
#                 if num==3: #Contribution_role
#                     for contribution_id,role in dic.items():
#                         contribution = URIRef("http://www.scoaring.com/ontology#%s")%contribution_id
#                         predict = URIRef("http://www.scoaring.com/ontology#role")
#                         g.add((contribution, predict, Literal(role)))
#             #####IF more roles add here#####
#     g.serialize(destination=('role_sequential_%d.txt')%num, format='turtle')
#create_triple_email("email_output3")
# ,totalList,num
def modify_triple_role(ttl,totalList):
    with open(ttl, "r",encoding='latin-1') as f:
        g = Graph()
        result = g.parse(f, format="turtle")
        #g.parse(ttl, format='turtle').decode('latin-1')
        #print(len(g))
        for subList in totalList:
            for contribution_id,paper_id,author_id,role,order in subList:
                print(type(order))
                contribution_unspecified = URIRef("http://www.scoaring.com/ontology#%s_%s_unspecified")%(paper_id,author_id)
                if (contribution_unspecified, None, None ) in g:
                    print("##############original#####################")
                    for s,p,o in g.triples((contribution_unspecified, None,None)):
                        print(s,p,o)
                        g.remove((contribution_unspecified, None, None))
                numInList=URIRef("http://scoaring.com/authorcontributions#placeInListOfAuthors")#placeInListOfAuthors
                isRole= URIRef("http://www.scoaring.com/ontology#role")#role
                contribution = URIRef("http://www.scoaring.com/ontology#%s")%contribution_id
                paper=URIRef("http://www.scoaring.com/ontology#%s")%paper_id
                author=URIRef("http://www.scoaring.com/ontology#%s")%author_id
                typeClass=URIRef("http://www.scoaring.com/ontology#contribution")
                isContributionByAuthor= URIRef("http://www.scoaring.com/ontology#isContributionByAuthor")#refersTo
                isContributionToPaper= URIRef("http://www.scoaring.com/ontology#isContributionToPaper")#refersTo
                contribution_role=Literal(role)
                namedIndividual = URIRef('http://www.w3.org/2002/07/owl#NamedIndividual')
                g.add((contribution,isRole,contribution_role))
                g.add((contribution, RDF.type, typeClass))
                g.add((contribution, RDF.type, namedIndividual))
                g.add((contribution,isContributionByAuthor, author))
                g.add((contribution,isContributionToPaper, paper))
                g.add((contribution,numInList,Literal(order)))
#                 print("##############after delete#####################")
#                 subj=URIRef(contribution_unspecified)
#                 for s,p,o in g.triples((subj, None,None)):
#                     print(s,p,o)
#                 print("###############generated####################")
#                 subj=URIRef(contribution)
#                 for s,p,o in g.triples((subj, None,None)):
#                     print(s,p,o)
    f.close()
    annotation="final_full"
    g.serialize(destination=('role_sequential_%s.ttl')%annotation, format='turtle')

# %%
import json
def main():
    processing=Processing()
    processing.NUM=2000#All papers
    email=[]
    role_result=[]
    count=1
    ce=1
#     role_1=[]#Contribution_Author totalList, containing sublist of each iteration's result
#     role_2=[]#Paper_Contribution
#     role_3=[]#Contribution_role
    for i in range(processing.NUM):
        #each of the paper
        try:
            print("##################")
            print(count)
            resourceId,authorList,authorPaper,authorCitation,authorID=processing.main(i)
#             print(authorList)
            extractor=AuthorInfoExtract()
            annotation=extractor.main(resourceId,authorList,authorPaper,authorCitation,authorID)
#             print(annotation)
            #author_role,paper_role,contribution_role=roleGenerator(annotation,resourceId)
#             result_list=roleGenerator(annotation,resourceId)
#             print(result_list)
#             role_result.append(result_list)
    #             role_1.append(author_role)
    #             role_2.append(paper_role)
    #             role_3.append(contribution_role)
            #print(author_role)
            emailExtractor=EmailInfoExtract()
            name_email=emailExtractor.main(resourceId,authorList,annotation)
            print(name_email)
            email.append(name_email)
            count+=1
        except:
            ce+=1
            print(ce)
            if ce>50:
                #modify_triple_role("Dataset v4 17-06-2020.ttl",role_result)
                create_triple_email(email)
#                 json_role = json.dumps(role_result)
#                 with open("role.json", 'w') as f:
#                     json.dump(json_role, f)
                print(finished)
                break
            continue
    print(ce)
    #modify_triple_role("Dataset v4 17-06-2020.ttl",role_result)
    #json_role = json.dumps(role_result)
    create_triple_email(email)
#     with open("role.json", 'w') as f:
#         json.dump(json_role, f)
    #create_triple_email(email)
main()

# %%
def contribution_paper_list():
    processing=Processing()
    extractor=AuthorInfoExtract()
    processing.NUM=2000#All papers
    email=[]
    author_contribution_paper=["1"]
    count=1
    ce=1
    for i in range(processing.NUM):
        try:
            print("##################")
            print(count)
            resourceId=processing.main(i)
            resourceId,authorList,authorPaper,authorCitation,authorID=processing.main(i)
            res=extractor.author_contribution(resourceId)
            print(res)
            if res ==True:
                author_contribution_paper.append(resourceId)
                print(resourceId)
            count+=1
        except:
            ce+=1
            print(ce)
            if ce>50:
                print(author_contribution_paper)
                f = open('contribution_paper_list.txt','w') #output.txt - 文件名称及格式 w - writing
                f.write(str(author_contribution_paper))
                f.close()
                print("finished")
                break
contribution_paper_list()
# Out:
# ##################
# 1
# P1297086 http://arxiv.org/pdf/1705.10467v2.pdf
# P1297086 http://arxiv.org/pdf/1705.10467v2.pdf
# False
# ##################
# 2
# P1297027 http://arxiv.org/pdf/1502.01094v2.pdf
# P1297027 http://arxiv.org/pdf/1502.01094v2.pdf
# False
# ##################
# 3
# P1297022 http://arxiv.org/pdf/1805.07103v2.pdf
# P1297022 http://arxiv.org/pdf/1805.07103v2.pdf
# False
# ##################
# 4
# P1296990 http://arxiv.org/pdf/1705.00609v1.pdf
# P1296990 http://arxiv.org/pdf/1705.00609v1.pdf
# False
# ##################
# 5
# P1296885 http://arxiv.org/pdf/1703.08840v2.pdf
# P1296885 http://arxiv.org/pdf/1703.08840v2.pdf
# False
# ##################
# 6
# P1296869 http://arxiv.org/pdf/1805.04623v1.pdf
# P1296869 http://arxiv.org/pdf/1805.04623v1.pdf
# False
# ##################
# 7
# P1296862 https://www.aclweb.org/anthology/W16-1626.pdf
# P1296862 https://www.aclweb.org/anthology/W16-1626.pdf
# False
# ##################
# 8
# P1296857 http://arxiv.org/pdf/1706.05781v1.pdf
# P1296857 http://arxiv.org/pdf/1706.05781v1.pdf
# False
# ##################
# 9
# P1296813 http://arxiv.org/pdf/1802.08241v4.pdf
# P1296813 http://arxiv.org/pdf/1802.08241v4.pdf
# False
# ##################
# 10
# P1296752 http://papers.nips.cc/paper/7205-robust-and-efficient-transfer-learning-with-hidden-parameter-markov-decision-processes.pdf
# P1296752 http://papers.nips.cc/paper/7205-robust-and-efficient-transfer-learning-with-hidden-parameter-markov-decision-processes.pdf
# False
# ##################
# 11
# P1296682 http://arxiv.org/pdf/1611.01642v1.pdf
# P1296682 http://arxiv.org/pdf/1611.01642v1.pdf
# False
# ##################
# 12
# P1296639 https://arxiv.org/pdf/1706.03922v6.pdf
# P1296639 https://arxiv.org/pdf/1706.03922v6.pdf
# False
# ##################
# 13
# P1296540 https://www.aclweb.org/anthology/P15-4022.pdf
# P1296540 https://www.aclweb.org/anthology/P15-4022.pdf
# False
# ##################
# 14
# P1296537 http://arxiv.org/pdf/1701.04082v2.pdf
# P1296537 http://arxiv.org/pdf/1701.04082v2.pdf
# False
# ##################
# 15
# P1296466 https://www.aclweb.org/anthology/W17-6314.pdf
# P1296466 https://www.aclweb.org/anthology/W17-6314.pdf
# False
# ##################
# 16
# P1296457 http://arxiv.org/pdf/1807.04595v2.pdf
# P1296457 http://arxiv.org/pdf/1807.04595v2.pdf
# P1285645 https://www.aclweb.org/anthology/P15-1148.pdf
# P1285645 https://www.aclweb.org/anthology/P15-1148.pdf
# False
# ##################
# 140
# P1285627 http://arxiv.org/pdf/1606.00253v1.pdf
# P1285627 http://arxiv.org/pdf/1606.00253v1.pdf
# False
# ##################
# 141
# P1285607 http://arxiv.org/pdf/1802.05642v2.pdf
# P1285607 http://arxiv.org/pdf/1802.05642v2.pdf
# False
# ##################
# 142
# P1285433 http://arxiv.org/pdf/1802.02538v2.pdf
# P1285433 http://arxiv.org/pdf/1802.02538v2.pdf
# False
# ##################
# 143
# P1285341 http://arxiv.org/pdf/1801.09392v2.pdf
# P1285341 http://arxiv.org/pdf/1801.09392v2.pdf
# False
# ##################
# 144
# P1285006 http://arxiv.org/pdf/1612.00385v2.pdf
# P1285006 http://arxiv.org/pdf/1612.00385v2.pdf
# False
# ##################
# 145
# P1284984 http://arxiv.org/pdf/1608.06656v1.pdf
# P1284984 http://arxiv.org/pdf/1608.06656v1.pdf
# False
# ##################
# 146
# P1284934 https://www.aclweb.org/anthology/C16-1285.pdf
# P1284934 https://www.aclweb.org/anthology/C16-1285.pdf
# False
# ##################
# 147
# P1284903 https://arxiv.org/pdf/1802.10349v2.pdf
# P1284903 https://arxiv.org/pdf/1802.10349v2.pdf
# False
# ##################
# 148
# P1284848 http://arxiv.org/pdf/1806.00720v1.pdf
# P1284848 http://arxiv.org/pdf/1806.00720v1.pdf
# False
# ##################
# 149
# P1284774 https://www.aclweb.org/anthology/C12-2053.pdf
# P1284774 https://www.aclweb.org/anthology/C12-2053.pdf
# False
# ##################
# 150
# P1284715 https://www.aclweb.org/anthology/P17-1115.pdf
# P1284715 https://www.aclweb.org/anthology/P17-1115.pdf
# False
# ##################
# 151
# P1284551 http://openaccess.thecvf.com/content_cvpr_2018/papers/Huang_Weakly-Supervised_Semantic_Segmentation_CVPR_2018_paper.pdf
# P1284551 http://openaccess.thecvf.com/content_cvpr_2018/papers/Huang_Weakly-Supervised_Semantic_Segmentation_CVPR_2018_paper.pdf
# False
# ##################
# 152
# P1284475 https://www.aclweb.org/anthology/C14-1212.pdf
# P1284475 https://www.aclweb.org/anthology/C14-1212.pdf
# False
# ##################
# 153
# P1284457 http://openaccess.thecvf.com/content_cvpr_2017/papers/Zhang_Deep_Future_Gaze_CVPR_2017_paper.pdf
# P1284457 http://openaccess.thecvf.com/content_cvpr_2017/papers/Zhang_Deep_Future_Gaze_CVPR_2017_paper.pdf
# False
# ##################
# 154
# P1284401 http://arxiv.org/pdf/1712.09392v1.pdf
# P1284401 http://arxiv.org/pdf/1712.09392v1.pdf
# False
# ##################
# 155
# P1284392 https://hal.archives-ouvertes.fr/hal-01351623/document
# P1284392 https://hal.archives-ouvertes.fr/hal-01351623/document
# False
# ##################
# 156
# P1284236 https://www.aclweb.org/anthology/D15-1160.pdf
# P1284236 https://www.aclweb.org/anthology/D15-1160.pdf
# False
# ##################
# 157
# P1284187 http://arxiv.org/pdf/1605.07571v2.pdf
# P1284187 http://arxiv.org/pdf/1605.07571v2.pdf
# False
# ##################
# 158
# P1284078 https://www.aclweb.org/anthology/N15-1002.pdf
# P1284078 https://www.aclweb.org/anthology/N15-1002.pdf
# False
# ##################
# 159
# P1284044 https://arxiv.org/pdf/1612.02103v3.pdf
# P1284044 https://arxiv.org/pdf/1612.02103v3.pdf
# False
# ##################
# 160
# P1283992 http://arxiv.org/pdf/1708.07517v2.pdf
# P1283992 http://arxiv.org/pdf/1708.07517v2.pdf
# False
# ##################
# 161
# P1283926 http://arxiv.org/pdf/1804.10574v3.pdf
# P1283926 http://arxiv.org/pdf/1804.10574v3.pdf
# False
# ##################
# 162
# P1283882 http://arxiv.org/pdf/1512.08183v5.pdf
# P1283882 http://arxiv.org/pdf/1512.08183v5.pdf
# False
# ##################
# 163
# P1283782 http://arxiv.org/pdf/1707.09700v2.pdf
# P1283782 http://arxiv.org/pdf/1707.09700v2.pdf
# False
# ##################
# 164
# P1283593 http://arxiv.org/pdf/1802.07191v3.pdf
# P1283593 http://arxiv.org/pdf/1802.07191v3.pdf
# False
# ##################
# 165
# P1283544 http://openaccess.thecvf.com/content_cvpr_2017/papers/Elbaz_3D_Point_Cloud_CVPR_2017_paper.pdf
# P1283544 http://openaccess.thecvf.com/content_cvpr_2017/papers/Elbaz_3D_Point_Cloud_CVPR_2017_paper.pdf
# False
# ##################
# 166
# P1283441 http://arxiv.org/pdf/1608.07470v1.pdf
# P1283441 http://arxiv.org/pdf/1608.07470v1.pdf
# False
# ##################
# 167
# P1283257 http://arxiv.org/pdf/1801.04540v2.pdf
# P1283257 http://arxiv.org/pdf/1801.04540v2.pdf
# False
# ##################
# 168
# P1283251 http://arxiv.org/pdf/1611.08461v3.pdf
# P1283251 http://arxiv.org/pdf/1611.08461v3.pdf
# False
# ##################
# 169
# P1283201 http://arxiv.org/pdf/1612.07146v3.pdf
# P1283201 http://arxiv.org/pdf/1612.07146v3.pdf
# False
# ##################
# 170
# P1283162 http://arxiv.org/pdf/1805.03989v2.pdf
# P1283162 http://arxiv.org/pdf/1805.03989v2.pdf
# False
# ##################
# 171
# P1283125 http://arxiv.org/pdf/1809.08782v2.pdf
# P1283125 http://arxiv.org/pdf/1809.08782v2.pdf
# False
# ##################
# 172
# P1283095 http://arxiv.org/pdf/1511.06067v3.pdf
# P1283095 http://arxiv.org/pdf/1511.06067v3.pdf
# False
# ##################
# 173
# P1283083 http://arxiv.org/pdf/1803.02453v3.pdf
# P1283083 http://arxiv.org/pdf/1803.02453v3.pdf
# False
# ##################
# 174
# P1283072 http://arxiv.org/pdf/1711.08028v4.pdf
# P1283072 http://arxiv.org/pdf/1711.08028v4.pdf
# False
# ##################
# 175
# P1282954 http://arxiv.org/pdf/1704.07863v2.pdf
# P1282954 http://arxiv.org/pdf/1704.07863v2.pdf
# False
# ##################
# 176
# P1282930 http://arxiv.org/pdf/1806.05759v3.pdf
# P1282930 http://arxiv.org/pdf/1806.05759v3.pdf
# False
# ##################
# 177
# P1282793 http://arxiv.org/pdf/1804.02257v2.pdf
# P1279960 http://arxiv.org/pdf/1708.06742v3.pdf
# False
# ##################
# 219
# P1279947 http://arxiv.org/pdf/1711.04323v1.pdf
# P1279947 http://arxiv.org/pdf/1711.04323v1.pdf
# False
# ##################
# 220
# P1279932 http://arxiv.org/pdf/1704.00028v3.pdf
# P1279932 http://arxiv.org/pdf/1704.00028v3.pdf
# False
# ##################
# 221
# P1279882 http://arxiv.org/pdf/1712.09948v1.pdf
# P1279882 http://arxiv.org/pdf/1712.09948v1.pdf
# False
# ##################
# 222
# P1279822 http://arxiv.org/pdf/1705.08551v3.pdf
# P1279822 http://arxiv.org/pdf/1705.08551v3.pdf
# False
# ##################
# 223
# P1279758 http://arxiv.org/pdf/1701.05517v1.pdf
# P1279758 http://arxiv.org/pdf/1701.05517v1.pdf
# False
# ##################
# 224
# P1279677 http://papers.nips.cc/paper/6581-improved-variational-inference-with-inverse-autoregressive-flow.pdf
# P1279677 http://papers.nips.cc/paper/6581-improved-variational-inference-with-inverse-autoregressive-flow.pdf
# False
# ##################
# 225
# P1279407 http://arxiv.org/pdf/1702.01691v2.pdf
# P1279407 http://arxiv.org/pdf/1702.01691v2.pdf
# False
# ##################
# 226
# P1279385 http://arxiv.org/pdf/1703.01560v3.pdf
# P1279385 http://arxiv.org/pdf/1703.01560v3.pdf
# False
# ##################
# 227
# P1279339 http://arxiv.org/pdf/1702.08811v3.pdf
# P1279339 http://arxiv.org/pdf/1702.08811v3.pdf
# False
# ##################
# 228
# P1279200 http://arxiv.org/pdf/1802.05027v2.pdf
# P1279200 http://arxiv.org/pdf/1802.05027v2.pdf
# False
# ##################
# 229
# P1279152 http://arxiv.org/pdf/1706.09516v5.pdf
# P1279152 http://arxiv.org/pdf/1706.09516v5.pdf
# False
# ##################
# 230
# P1279060 http://arxiv.org/pdf/1805.12018v2.pdf
# P1279060 http://arxiv.org/pdf/1805.12018v2.pdf
# False
# ##################
# 231
# P1278999 http://arxiv.org/pdf/1611.08373v1.pdf
# P1278999 http://arxiv.org/pdf/1611.08373v1.pdf
# False
# ##################
# 232
# P1278942 http://arxiv.org/pdf/1810.00956v1.pdf
# P1278942 http://arxiv.org/pdf/1810.00956v1.pdf
# False
# ##################
# 233
# P1278920 http://arxiv.org/pdf/1805.11565v4.pdf
# P1278920 http://arxiv.org/pdf/1805.11565v4.pdf
# False
# ##################
# 234
# P1278884 http://arxiv.org/pdf/1704.03225v1.pdf
# P1278884 http://arxiv.org/pdf/1704.03225v1.pdf
# False
# ##################
# 235
# P1278759 http://arxiv.org/pdf/1802.05668v1.pdf
# P1278759 http://arxiv.org/pdf/1802.05668v1.pdf
# False
# ##################
# 236
# P1278646 http://arxiv.org/pdf/1603.01029v2.pdf
# P1278646 http://arxiv.org/pdf/1603.01029v2.pdf
# False
# ##################
# 237
# P1278562 http://arxiv.org/pdf/1510.06423v4.pdf
# P1278562 http://arxiv.org/pdf/1510.06423v4.pdf
# False
# ##################
# 238
# P1278548 http://arxiv.org/pdf/1710.08969v1.pdf
# P1278548 http://arxiv.org/pdf/1710.08969v1.pdf
# P1277044 http://arxiv.org/pdf/1807.11546v1.pdf
# False
# ##################
# 260
# P1276768 http://arxiv.org/pdf/1504.04343v2.pdf
# P1276768 http://arxiv.org/pdf/1504.04343v2.pdf
# False
# ##################
# 261
# P1276661 http://arxiv.org/pdf/1803.10417v3.pdf
# P1276661 http://arxiv.org/pdf/1803.10417v3.pdf
# True
# P1276661
# ##################
# 262
# P1276433 http://arxiv.org/pdf/1706.04124v2.pdf
# P1276433 http://arxiv.org/pdf/1706.04124v2.pdf
# False
# ##################
# 263
# P1276299 http://arxiv.org/pdf/1602.00260v2.pdf
# P1276299 http://arxiv.org/pdf/1602.00260v2.pdf
# False
# ##################
# 264
# P1276276 https://www.aclweb.org/anthology/P16-2089.pdf
# P1276276 https://www.aclweb.org/anthology/P16-2089.pdf
# False
# ##################
# 265
# P1276205 https://www.aclweb.org/anthology/W17-2310.pdf
# P1276205 https://www.aclweb.org/anthology/W17-2310.pdf
# False
# ##################
# 266
# P1276002 http://arxiv.org/pdf/1711.07387v5.pdf
# P1276002 http://arxiv.org/pdf/1711.07387v5.pdf
# True
# P1276002
# ##################
# 267
# P1275887 http://arxiv.org/pdf/1804.04732v2.pdf
# P1275887 http://arxiv.org/pdf/1804.04732v2.pdf
# False
# ##################
# 268
# P1275845 http://arxiv.org/pdf/1604.05529v3.pdf
# P1275845 http://arxiv.org/pdf/1604.05529v3.pdf
# False
# ##################
# 269
# P1275741 http://arxiv.org/pdf/1705.08931v1.pdf
# P1275741 http://arxiv.org/pdf/1705.08931v1.pdf
# False
# ##################
# 270
# P1275702 https://www.aclweb.org/anthology/K17-1038.pdf
# P1275702 https://www.aclweb.org/anthology/K17-1038.pdf
# False
# ##################
# 271
# P1275478 http://arxiv.org/pdf/1602.05307v1.pdf
# P1275478 http://arxiv.org/pdf/1602.05307v1.pdf
# False
# ##################
# 272
# P1275267 http://arxiv.org/pdf/1805.10572v1.pdf
# P1275267 http://arxiv.org/pdf/1805.10572v1.pdf
# False
# ##################
# 273
# P1275168 http://arxiv.org/pdf/1611.08568v3.pdf
# P1275168 http://arxiv.org/pdf/1611.08568v3.pdf
# False
# ##################
# 274
# P1275164 http://arxiv.org/pdf/1307.5302v3.pdf
# P1275164 http://arxiv.org/pdf/1307.5302v3.pdf
# False
# ##################
# 275
# P1275135 http://arxiv.org/pdf/1507.01839v2.pdf
# P1275135 http://arxiv.org/pdf/1507.01839v2.pdf
# False
# ##################
# 276
# P1275068 https://www.aclweb.org/anthology/D18-1093.pdf
# P1275068 https://www.aclweb.org/anthology/D18-1093.pdf
# False
# ##################
# 277
# P1274930 https://www.aclweb.org/anthology/P15-2062.pdf
# P1274930 https://www.aclweb.org/anthology/P15-2062.pdf
# False
# ##################
# 278
# P1274848 http://arxiv.org/pdf/1511.03962v4.pdf
# P1274848 http://arxiv.org/pdf/1511.03962v4.pdf
# False
# ##################
# 279
# P1274817 https://arxiv.org/pdf/1806.07366v5.pdf
# P1274817 https://arxiv.org/pdf/1806.07366v5.pdf
# False
# ##################
# 280
# False
# ##################
# 300
# P1271921 https://arxiv.org/pdf/1612.01051v4.pdf
# P1271921 https://arxiv.org/pdf/1612.01051v4.pdf
# 4
# ##################
# 300
# P1271856 http://arxiv.org/pdf/1808.08732v1.pdf
# P1271856 http://arxiv.org/pdf/1808.08732v1.pdf
# False
# ##################
# 301
# P1271796 http://arxiv.org/pdf/1611.02185v5.pdf
# P1271796 http://arxiv.org/pdf/1611.02185v5.pdf
# False
# ##################
# 302
# P1271715 http://arxiv.org/pdf/1801.02209v2.pdf
# P1271715 http://arxiv.org/pdf/1801.02209v2.pdf
# False
# ##################
# 303
# P1271171 http://arxiv.org/pdf/1712.00731v1.pdf
# P1271171 http://arxiv.org/pdf/1712.00731v1.pdf
# False
# ##################
# 304
# P1271049 http://arxiv.org/pdf/1701.05265v1.pdf
# P1271049 http://arxiv.org/pdf/1701.05265v1.pdf
# False
# ##################
# 305
# P1270913 https://www.aaai.org/ocs/index.php/AAAI/AAAI18/paper/viewFile/17146/16755
# P1270913 https://www.aaai.org/ocs/index.php/AAAI/AAAI18/paper/viewFile/17146/16755
# False
# ##################
# 306
# P1270753 http://arxiv.org/pdf/1705.04862v2.pdf
# P1270753 http://arxiv.org/pdf/1705.04862v2.pdf
# False
# ##################
# 307
# P1270568 http://proceedings.mlr.press/v70/wang17m/wang17m.pdf
# P1270568 http://proceedings.mlr.press/v70/wang17m/wang17m.pdf
# False
# ##################
# 308
# P1270405 http://arxiv.org/pdf/1703.04782v3.pdf
# P1270405 http://arxiv.org/pdf/1703.04782v3.pdf
# False
# ##################
# 309
# P1270296 http://arxiv.org/pdf/1806.04470v2.pdf
# P1270296 http://arxiv.org/pdf/1806.04470v2.pdf
# False
# ##################
# 310
# P1270025 http://arxiv.org/pdf/1706.07522v1.pdf
# P1270025 http://arxiv.org/pdf/1706.07522v1.pdf
# False
# ##################
# 311
# P1269992 http://arxiv.org/pdf/1706.00457v1.pdf
# P1269992 http://arxiv.org/pdf/1706.00457v1.pdf
# False
# ##################
# 312
# P1269976 http://arxiv.org/pdf/1703.06045v5.pdf
# P1269976 http://arxiv.org/pdf/1703.06045v5.pdf
# False
# ##################
# 313
# P1269894 http://arxiv.org/pdf/1707.06480v1.pdf
# P1269894 http://arxiv.org/pdf/1707.06480v1.pdf
# False
# ##################
# 314
# P1269656 http://arxiv.org/pdf/1711.08389v4.pdf
# P1269656 http://arxiv.org/pdf/1711.08389v4.pdf
# False
# ##################
# 315
# P1269610 http://openaccess.thecvf.com/content_cvpr_2018/papers/An_A_PID_Controller_CVPR_2018_paper.pdf
# P1269610 http://openaccess.thecvf.com/content_cvpr_2018/papers/An_A_PID_Controller_CVPR_2018_paper.pdf
# False
# ##################
# 316
# P1269598 http://arxiv.org/pdf/1801.06761v2.pdf
# P1269598 http://arxiv.org/pdf/1801.06761v2.pdf
# False
# ##################
# 317
# P1269536 https://www.aclweb.org/anthology/C18-1037.pdf
# P1269536 https://www.aclweb.org/anthology/C18-1037.pdf
# False
# ##################
# 318
# P1267207 http://arxiv.org/pdf/1703.10332v3.pdf
# False
# ##################
# 339
# P1267165 http://arxiv.org/pdf/1707.08435v4.pdf
# P1267165 http://arxiv.org/pdf/1707.08435v4.pdf
# False
# ##################
# 340
# P1267089 https://www.aclweb.org/anthology/N15-1118.pdf
# P1267089 https://www.aclweb.org/anthology/N15-1118.pdf
# False
# ##################
# 341
# P1266737 https://www.aclweb.org/anthology/P13-1115.pdf
# P1266737 https://www.aclweb.org/anthology/P13-1115.pdf
# False
# ##################
# 342
# P1266462 http://arxiv.org/pdf/1604.08723v1.pdf
# P1266462 http://arxiv.org/pdf/1604.08723v1.pdf
# False
# ##################
# 343
# P1266372 http://arxiv.org/pdf/1803.06070v2.pdf
# P1266372 http://arxiv.org/pdf/1803.06070v2.pdf
# False
# ##################
# 344
# P1266369 https://www.aclweb.org/anthology/P16-4009.pdf
# P1266369 https://www.aclweb.org/anthology/P16-4009.pdf
# False
# ##################
# 345
# P1266184 http://arxiv.org/pdf/1711.06721v3.pdf
# P1266184 http://arxiv.org/pdf/1711.06721v3.pdf
# False
# ##################
# 346
# P1266103 https://www.aclweb.org/anthology/P14-1079.pdf
# P1266103 https://www.aclweb.org/anthology/P14-1079.pdf
# False
# ##################
# 347
# P1266020 http://arxiv.org/pdf/1805.03183v2.pdf
# P1266020 http://arxiv.org/pdf/1805.03183v2.pdf
# False
# ##################
# 348
# P1265960 https://www.aclweb.org/anthology/C18-2028.pdf
# P1265960 https://www.aclweb.org/anthology/C18-2028.pdf
# False
# ##################
# 349
# P1265921 http://arxiv.org/pdf/1803.00949v2.pdf
# P1265921 http://arxiv.org/pdf/1803.00949v2.pdf
# False
# ##################
# 350
# P1265905 https://arxiv.org/pdf/1611.05088v4.pdf
# P1265905 https://arxiv.org/pdf/1611.05088v4.pdf
# False
# ##################
# 351
# P1265859 https://arxiv.org/pdf/1711.04725v1.pdf
# P1265859 https://arxiv.org/pdf/1711.04725v1.pdf
# False
# ##################
# 352
# P1265390 http://arxiv.org/pdf/1610.06940v3.pdf
# P1265390 http://arxiv.org/pdf/1610.06940v3.pdf
# False
# ##################
# 353
# P1265181 http://openaccess.thecvf.com/content_cvpr_2016/papers/Perazzi_A_Benchmark_Dataset_CVPR_2016_paper.pdf
# P1265181 http://openaccess.thecvf.com/content_cvpr_2016/papers/Perazzi_A_Benchmark_Dataset_CVPR_2016_paper.pdf
# False
# ##################
# 354
# P1265163 http://arxiv.org/pdf/1609.05119v1.pdf
# P1265163 http://arxiv.org/pdf/1609.05119v1.pdf
# False
# ##################
# 355
# P1265071 https://www.aclweb.org/anthology/P18-1075.pdf
# P1265071 https://www.aclweb.org/anthology/P18-1075.pdf
# False
# ##################
# 356
# P1265057 http://arxiv.org/pdf/1702.08165v2.pdf
# P1265057 http://arxiv.org/pdf/1702.08165v2.pdf
# False
# ##################
# 357
# P1264762 http://arxiv.org/pdf/1804.09057v1.pdf
# P1264762 http://arxiv.org/pdf/1804.09057v1.pdf
# False
# ##################
# 358
# P1264722 http://arxiv.org/pdf/1708.01464v1.pdf
# P1264722 http://arxiv.org/pdf/1708.01464v1.pdf
# False
# ##################
# 359
# P1264648 http://arxiv.org/pdf/1706.03059v2.pdf
# P1264648 http://arxiv.org/pdf/1706.03059v2.pdf
# False
# ##################
# 360
# P1264583 http://arxiv.org/pdf/1603.06076v3.pdf
# P1264583 http://arxiv.org/pdf/1603.06076v3.pdf
# False
# ##################
# 361
# P1264558 http://arxiv.org/pdf/1804.09779v2.pdf
# P1264558 http://arxiv.org/pdf/1804.09779v2.pdf
# False
# ##################
# 362
# P1264477 http://arxiv.org/pdf/1711.02391v1.pdf
# P1264477 http://arxiv.org/pdf/1711.02391v1.pdf
# False
# ##################
# 363
# P1264291 http://arxiv.org/pdf/1707.07265v1.pdf
# P1264291 http://arxiv.org/pdf/1707.07265v1.pdf
# False
# ##################
# 364
# P1264284 http://arxiv.org/pdf/1809.03406v1.pdf
# P1264284 http://arxiv.org/pdf/1809.03406v1.pdf
# False
# ##################
# 365
# P1264281 http://arxiv.org/pdf/1608.04236v2.pdf
# P1264281 http://arxiv.org/pdf/1608.04236v2.pdf
# False
# ##################
# 366
# P1264226 http://arxiv.org/pdf/1711.05186v2.pdf
# P1264226 http://arxiv.org/pdf/1711.05186v2.pdf
# False
# ##################
# 367
# P1264105 http://openaccess.thecvf.com/content_ECCV_2018/papers/Xin_Li_Contour_Knowledge_Transfer_ECCV_2018_paper.pdf
# P1264105 http://openaccess.thecvf.com/content_ECCV_2018/papers/Xin_Li_Contour_Knowledge_Transfer_ECCV_2018_paper.pdf
# False
# ##################
# 368
# P1264098 https://www.aclweb.org/anthology/C18-1128.pdf
# P1264098 https://www.aclweb.org/anthology/C18-1128.pdf
# False
# ##################
# 369
# ...
# P1169566 http://arxiv.org/pdf/1612.05460v2.pdf
# False
# ##################
# 1323
# P1169486 https://www.aclweb.org/anthology/C16-1328.pdf
# P1169486 https://www.aclweb.org/anthology/C16-1328.pdf
# False
# ##################
# 1324
# P1169394 http://arxiv.org/pdf/1503.02801v1.pdf
# P1169394 http://arxiv.org/pdf/1503.02801v1.pdf
# False
# ##################
# 1325
# P1168967 http://arxiv.org/pdf/1606.04366v3.pdf
# P1168967 http://arxiv.org/pdf/1606.04366v3.pdf
# False
# ##################
# 1326
# P1168892 http://arxiv.org/pdf/1804.00308v1.pdf
# P1168892 http://arxiv.org/pdf/1804.00308v1.pdf
# False
# ##################
# 1327
# P1168844 http://arxiv.org/pdf/1707.06682v1.pdf
# P1168844 http://arxiv.org/pdf/1707.06682v1.pdf
# True
# P1168844
# ##################
# 1328
# P1168670 http://arxiv.org/pdf/1607.01750v2.pdf
# P1168670 http://arxiv.org/pdf/1607.01750v2.pdf
# True
# P1168670
# ##################
# 1329
# P1168574 http://arxiv.org/pdf/1802.05766v1.pdf
# P1168574 http://arxiv.org/pdf/1802.05766v1.pdf
# False
# ##################
# 1330
# P1168559 http://arxiv.org/pdf/1805.06605v2.pdf
# P1168559 http://arxiv.org/pdf/1805.06605v2.pdf
# False
# ##################
# 1331
# P1168335 http://arxiv.org/pdf/1709.02023v2.pdf
# P1168335 http://arxiv.org/pdf/1709.02023v2.pdf
# False
# ##################
# 1332
# P1168319 https://arxiv.org/pdf/1803.00197v4.pdf
# P1168319 https://arxiv.org/pdf/1803.00197v4.pdf
# False
# ##################
# 1333
# P1168128 http://arxiv.org/pdf/1704.03114v2.pdf
# P1168128 http://arxiv.org/pdf/1704.03114v2.pdf
# False
# ##################
# 1334
# P1167928 http://arxiv.org/pdf/1611.05009v4.pdf
# P1167928 http://arxiv.org/pdf/1611.05009v4.pdf
# False
# ##################
# 1335
# P1167544 http://arxiv.org/pdf/1705.08584v3.pdf
# P1167544 http://arxiv.org/pdf/1705.08584v3.pdf
# False
# ##################
# 1336
# P1167524 http://arxiv.org/pdf/1812.01193v2.pdf
# P1167524 http://arxiv.org/pdf/1812.01193v2.pdf
# False
# ##################
# 1337
# P1167470 http://arxiv.org/pdf/1707.06588v3.pdf
# P1167470 http://arxiv.org/pdf/1707.06588v3.pdf
# False
# ##################
# 1338
# P1167405 http://arxiv.org/pdf/1712.08207v3.pdf
# P1167405 http://arxiv.org/pdf/1712.08207v3.pdf
# False
# ##################
# 1339
# P1167306 http://arxiv.org/pdf/1306.4080v4.pdf
# P1167306 http://arxiv.org/pdf/1306.4080v4.pdf
# False
# ##################
# 1340
# P1167305 http://arxiv.org/pdf/1706.05150v1.pdf
# P1167305 http://arxiv.org/pdf/1706.05150v1.pdf
# False
# ##################
# 1341
# P1167303 http://arxiv.org/pdf/1711.09125v2.pdf
# P1167303 http://arxiv.org/pdf/1711.09125v2.pdf
# False
# ##################
# 1342
# P1167229 https://www.aclweb.org/anthology/K17-1010.pdf
# P1167229 https://www.aclweb.org/anthology/K17-1010.pdf
# False
# ##################
# 1343
# P1167100 http://arxiv.org/pdf/1805.11073v1.pdf
# P1167100 http://arxiv.org/pdf/1805.11073v1.pdf
# False
# ##################
# 1344
# P1167032 http://arxiv.org/pdf/1804.05526v3.pdf
# P1167032 http://arxiv.org/pdf/1804.05526v3.pdf
# False
# ##################
# 1345
# P1166893 http://arxiv.org/pdf/1709.10053v2.pdf
# P1166893 http://arxiv.org/pdf/1709.10053v2.pdf
# False
# ##################
# 1346
# P1166860 http://arxiv.org/pdf/1609.04836v2.pdf
# P1166860 http://arxiv.org/pdf/1609.04836v2.pdf
# False
# ##################
# 1347
# P1166779 http://arxiv.org/pdf/1705.09655v2.pdf
# P1166779 http://arxiv.org/pdf/1705.09655v2.pdf
# False
# ##################
# 1348
# P1166753 http://openaccess.thecvf.com/content_cvpr_2017/papers/Feichtenhofer_Spatiotemporal_Multiplier_Networks_CVPR_2017_paper.pdf
# P1166753 http://openaccess.thecvf.com/content_cvpr_2017/papers/Feichtenhofer_Spatiotemporal_Multiplier_Networks_CVPR_2017_paper.pdf
# False
# ##################
# 1349
# P1166670 http://arxiv.org/pdf/1708.01809v1.pdf
# P1166670 http://arxiv.org/pdf/1708.01809v1.pdf
# False
# ##################
# 1350
# P1166588 http://arxiv.org/pdf/1806.04291v1.pdf
# P1166588 http://arxiv.org/pdf/1806.04291v1.pdf
# False
# ##################
# 1351
# P1166163 http://arxiv.org/pdf/1802.02852v2.pdf
# P1166163 http://arxiv.org/pdf/1802.02852v2.pdf
# False
# ##################
# 1352
# P1165923 http://arxiv.org/pdf/1708.06525v4.pdf
# P1165923 http://arxiv.org/pdf/1708.06525v4.pdf
# False
# ##################
# 1353
# P1165825 http://arxiv.org/pdf/1709.03708v1.pdf
# P1165825 http://arxiv.org/pdf/1709.03708v1.pdf
# False
# ##################
# 1354
# P1165414 http://openaccess.thecvf.com/content_cvpr_2018/papers/Wang_Salient_Object_Detection_CVPR_2018_paper.pdf
# P1165414 http://openaccess.thecvf.com/content_cvpr_2018/papers/Wang_Salient_Object_Detection_CVPR_2018_paper.pdf
# False
# ##################
# 1355
# P1164962 http://arxiv.org/pdf/1711.06178v1.pdf
# P1164962 http://arxiv.org/pdf/1711.06178v1.pdf
# False
# ##################
# 1356
# P1164754 http://arxiv.org/pdf/1802.04942v5.pdf
# P1164754 http://arxiv.org/pdf/1802.04942v5.pdf
# False
# ##################
# 1357
# P1164617 http://arxiv.org/pdf/1611.02261v4.pdf
# P1164617 http://arxiv.org/pdf/1611.02261v4.pdf
# False
# ##################
# 1358
# P1164222 https://www.aclweb.org/anthology/S14-2139.pdf
# P1164222 https://www.aclweb.org/anthology/S14-2139.pdf
# False
# ##################
# 1359
# P1164072 http://arxiv.org/pdf/1808.09542v1.pdf
# P1164072 http://arxiv.org/pdf/1808.09542v1.pdf
# False
# ##################
# 1360
# P1163841 http://arxiv.org/pdf/1502.03655v2.pdf
# P1163841 http://arxiv.org/pdf/1502.03655v2.pdf
# False
# ##################
# 1361
# P1163724 http://arxiv.org/pdf/1711.01004v2.pdf
# P1163724 http://arxiv.org/pdf/1711.01004v2.pdf
# False
# ##################
# 1362
# P1163711 http://arxiv.org/pdf/1406.1584v3.pdf
# P1163711 http://arxiv.org/pdf/1406.1584v3.pdf
# False
# ##################
# 1363
# P1163655 http://arxiv.org/pdf/1706.02515v5.pdf
# P1163655 http://arxiv.org/pdf/1706.02515v5.pdf
# False
# ##################
# 1364
# P1163612 http://arxiv.org/pdf/1707.07165v1.pdf
# P1163612 http://arxiv.org/pdf/1707.07165v1.pdf
# False
# ##################
# 1365
# P1163611 http://papers.nips.cc/paper/6367-deep-neural-networks-with-inexact-matching-for-person-re-identification.pdf
# P1163611 http://papers.nips.cc/paper/6367-deep-neural-networks-with-inexact-matching-for-person-re-identification.pdf
# False
# ##################
# 1366
# P1163596 http://arxiv.org/pdf/1706.00188v1.pdf
# P1163596 http://arxiv.org/pdf/1706.00188v1.pdf
# False
# ##################
# 1367
# P1163591 http://arxiv.org/pdf/1511.06448v3.pdf
# P1163591 http://arxiv.org/pdf/1511.06448v3.pdf
# False
# ##################
# 1368
# P1163574 http://arxiv.org/pdf/1706.06905v2.pdf
# P1163574 http://arxiv.org/pdf/1706.06905v2.pdf
# False
# ##################
# 1369
# P1156706 http://arxiv.org/pdf/1507.02159v1.pdf
# False
# ##################
# 1429
# P1156614 http://arxiv.org/pdf/1709.04496v2.pdf
# P1156614 http://arxiv.org/pdf/1709.04496v2.pdf
# False
# ##################
# 1430
# P1156541 https://arxiv.org/pdf/1806.06371v2.pdf
# P1156541 https://arxiv.org/pdf/1806.06371v2.pdf
# False
# ##################
# 1431
# P1156386 http://arxiv.org/pdf/1706.03686v3.pdf
# P1156386 http://arxiv.org/pdf/1706.03686v3.pdf
# False
# ##################
# 1432
# P1156365 http://arxiv.org/pdf/1803.03095v1.pdf
# P1156365 http://arxiv.org/pdf/1803.03095v1.pdf
# False
# ##################
# 1433
# P1156351 http://arxiv.org/pdf/1710.01269v1.pdf
# P1156351 http://arxiv.org/pdf/1710.01269v1.pdf
# True
# P1156351
# ##################
# 1434
# 12
# ##################
# 1434
# 13
# ##################
# 1434
# 14
# ##################
# 1434
# 15
# ##################
# 1434
# 16
# ##################
# 1434
# 17
# ##################
# 1434
# 18
# ##################
# 1434
# 19
# ##################
# 1434
# 20
# ##################
# 1434
# 21
# ##################
# 1434
# 22
# ##################
# 1434
# 23
# ##################
# 1434
# 24
# ##################
# 1434
# 25
# ##################
# 1434
# 26
# ##################
# 1434
# 27
# ##################
# 1434
# 28
# ##################
# 1434
# 29
# ##################
# 1434
# 30
# ##################
# 1434
# 31
# ##################
# 1434
# 32
# ##################
# 1434
# 33
# ##################
# 1434
# 34
# ##################
# 1434
# 35
# ##################
# 1434
# 36
# ##################
# 1434
# 37
# ##################
# 1434
# 38
# ##################
# 1434
# 39
# ##################
# 1434
# 40
# ##################
# 1434
# 41
# ##################
# 1434
# 42
# ##################
# 1434
# 43
# ##################
# 1434
# 44
# ##################
# 1434
# 45
# ##################
# 1434
# 46
# ##################
# 1434
# 47
# ##################
# 1434
# 48
# ##################
# 1434
# 49
# ##################
# 1434
# 50
# ##################
# 1434
# 51
# ['1', 'P1290849', 'P1276661', 'P1276002', 'P1243761', 'P1233694', 'P1222289', 'P1220879', 'P1215804', 'P1192263', 'P1187997', 'P1183547', 'P1168844', 'P1168670', 'P1156351']
# finished

# %%
# g1 = Graph()
# g1.parse("role_sequential_final.ttl", format='turtle')
# print("g1 has {} triples".format(len(g1)))

# g2 = Graph()
# g2.parse("email_sequential.ttl", format='turtle')
# print("g2 has {} triples".format(len(g2)))

# graph = g1 + g2
# print("g1 + g2 has {} triples".format(len(graph)))
# graph.serialize(destination=('Dataset_v4.ttl'), format='turtle')
g1 = Graph()
g1.parse("role_sequential_final_full.ttl", format='turtle')
print("g1 has {} triples".format(len(g1)))

# g2 = Graph()
# g2.parse("Dataset_v42.ttl", format='turtle')
# print("g2 has {} triples".format(len(g2)))

g3=Graph()
g3.parse("e'm.ttl", format='turtle')
print("g3 has {} triples".format(len(g3)))
graph = g1 + g3
print("g1 + g2 has {} triples".format(len(graph)))
graph.serialize(destination=('Dataset_v402.ttl'), format='turtle')
# Out:
# g1 has 92996 triples
# g3 has 88277 triples
# g1 + g2 has 94425 triples
