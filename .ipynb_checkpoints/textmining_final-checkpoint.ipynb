# %% [markdown]
# Before running the code, several dependant package need to be installed, skip if it already exists.

# %%
pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in /Applications/anaconda3/lib/python3.7/site-packages (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading https://files.pythonhosted.org/packages/0b/04/f62d5834c2bdf90afcaeb23bb5241033c44e27000de64ad8472253daa4a8/pdfminer.six-20200402-py3-none-any.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 5.3MB/s eta 0:00:01
# Requirement already satisfied: chardet; python_version > "3.0" in /Applications/anaconda3/lib/python3.7/site-packages (from pdfminer.six) (3.0.4)
# Requirement already satisfied: pycryptodome in /Applications/anaconda3/lib/python3.7/site-packages (from pdfminer.six) (3.9.7)
# Requirement already satisfied: sortedcontainers in /Applications/anaconda3/lib/python3.7/site-packages (from pdfminer.six) (2.1.0)
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20200402
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /Applications/anaconda3/lib/python3.7/site-packages (0.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-Levenshtein

# %% [markdown]
# Firstly, we make connection with database with pymysql api.

# %%
import pymysql
#https://cloud.tencent.com/developer/article/1395339
import urllib
import pdfminer
import copy
from io import StringIO
from io import BytesIO
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfpage import PDFTextExtractionNotAllowed
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice
from pdfminer.layout import *
from pdfminer.converter import PDFPageAggregator
from urllib.request import Request
from urllib.request import urlopen
#input basic info about database
class Processing():
    '''
    This class is used to connect with the mysql database, download the paper and convert to the txt
    The result return resourceId(string),authorList(List),authorPaper,authorCitation and authorID
    '''
    def __init__(self):
        self.NUM=3
        self.conn=pymysql.connect(host='mysql24.ezhostingserver.com', port=3306, user='krw',password='Y>!V@N_26@]cfJ7(')

    def connection(self):
        query_result=[]
        #cursor is the current point we focus on, which could execute sql command.
        cursor=self.conn.cursor()
        #Here rw is the databse name and training_view is a view for requesting data. The execution should be around 30s.
        cursor.execute("SELECT * FROM krw.training_paper_view group by id limit %s;",self.NUM)
        for r in cursor:
            query_result.append(list(r))
        cursor.close()
        return query_result
    #lst
    def pre_processing(self,index,query_result):
        resourceId=query_result[index][2]
        authorNum=query_result[index][3]
        url=query_result[index][7]
        #print(resourceId,url)
        #name=lst[NUM][6]
        webList=["acmweb","aclweb"]
        for web in webList:
            if web in url:
                #pattern = re.compile(ur'^((https|http|ftp|rtsp|mms)?:\/\/)[^\s]+/')
                #str = u''
                url=url+".pdf"
            #name=pattern.search(str)
        #url="https://arxiv.org/pdf/"+str(name)+".pdf"
        print(resourceId,url)
        return resourceId,url
        
    def query(self,index, resourceId):
        temp=[]
        authorList=[]
        #Here krw is the databse name and training_view is a view for requesting data. The execution should be around 30s.
        #conn=pymysql.connect(host='mysql24.ezhostingserver.com', port=3306, user='krw',password='Y>!V@N_26@]cfJ7(')
        cursor=self.conn.cursor()
        #Here krw is the databse name and training_view is a view for requesting data. The execution should be around 30s.
        cursor.execute("SELECT * FROM krw.training_author_view where paper_id=(%s) group by name;",resourceId)
        cursor.close()
        authorPaper={}
        authorCitation={}
        authorID={}
        for r in cursor:
            temp.append(list(r))
        #print(temp)
        for line in temp:
            authorList.append(line[1])
            authorPaper[line[1]]=[line[3]]
            authorCitation[line[1]]=[line[4]]
            authorID[line[1]]=[line[0]]
        #print(authorList)
        return authorList,authorPaper,authorCitation,authorID

    def onlinePdfToTxt(self,dataIo,new_path):
        # Create PDF Parser
        parser = PDFParser(dataIo)
        # Create PDFDocument
        document = PDFDocument(parser)
        # Is it okay for extraction?
        if not document.is_extractable:
            raise PDFTextExtractionNotAllowed
        else:
            # Create PDF Manager
            resmag =PDFResourceManager()
            # Setting parameters
            laparams=LAParams()
            # Createing PDF device
            # device=PDFDevice(resmag )
            device=PDFPageAggregator(resmag ,laparams=laparams)
            # Create PDF explainer
            interpreter=PDFPageInterpreter(resmag ,device)
            # For each page
            for page in PDFPage.create_pages(document):
                interpreter.process_page(page)
                # accept this page's LTP object
                layout=device.get_result()
                for y in layout:
                    try:
                        if(isinstance(y,LTTextBoxHorizontal)):
                            with open('%s'%(new_path),'a',encoding="utf-8") as f:
                                f.write(y.get_text()+'\n')
                                #print("Success！")
                    except:
                        print("Failed")
                        
    def main(self,index):
        query_result=self.connection()
#         for index in range(len(NUM)):
        resourceId,url=self.pre_processing(index,query_result)
        html = urllib.request.urlopen(urllib.request.Request(url)).read()
        dataIo = BytesIO(html)
        self.onlinePdfToTxt(dataIo,'txt/'+str(resourceId)+'.txt')
        authorList,authorPaper,authorCitation,authorID=self.query(index,resourceId)
        return resourceId,authorList,authorPaper,authorCitation,authorID
    
# processing=Processing()
# processing.NUM=5
# resourceId,authorList,authorPaper,authorCitation,authorID=processing.main(4)
# print(authorList)

# %% [markdown]
# After excution we obtained a 2-dimensional matrix with each row represents a paper. Next, we constract a url based on arXiv id.

# %% [markdown]
# By following command we could access pdf by url and convert pdf 2 txt file and store at local.

# %%
import spacy
import re
import copy
from spacy import displacy
from collections import Counter
import en_core_web_sm
from Levenshtein import *
#nlp = en_core_web_sm.load()
class AuthorInfoExtract():
    '''
    This class is used to extract special author with annotations
    The result is orgnized as a list containing dictionaries
    '''
    STARS=["*",'∗']
    CROSS=["†","‡"]
    def detectCapitalUse(self, word: str) -> bool:
        
        is_upper = [c.isupper() for c in word]          # Upper 
        is_lower = [c.islower() for c in word]          # Lower
        
#         if all(is_upper) or all(is_lower):              # All upper or lower
#             return True                         

        if any(is_upper):                               # Upper and lower
            return is_upper[0] and all(is_lower[1:])    # Only first is upper 
        
    def locateContext(self,resourceId):
        file = open('txt/'+str(resourceId)+'.txt',encoding="utf-8")
        strings=file.read()
        symbolList=["Abstract",'Abstract.','ABSTRACT','ABSTRACT.']
        for symbol in symbolList:
            #if name in strings:
            if strings.find(symbol):
                output=strings[0:strings.find(symbol)]
                break
            else:
                print(symbol+" not found!")
                output==strings[0:3000]
        file.close()
        output=output.replace('\n', ' . ').replace('\r', ' ')
        output=output.split(" ")
        return (output)
#     def judge(x):
#         return bool(re.search(r'\d', x))

    def acknowledgementJudgement(self,resourceId,authorList,corre):
        file = open('txt/'+str(resourceId)+'.txt',encoding="utf-8")
        strings=file.read()
        symbolList=["Acknowledgement",'ACKNOWLEDGEMENT','Acknowledgements','ACKNOWLEDGEMENTS','ACK']
        for symbol in symbolList:
            #if name in strings:
            if strings.find(symbol):
                output=strings[strings.find(symbol):strings.find(symbol)+1000]
                break
            else:
                print(symbol+" not found!")
                #output==strings[0:3000]
        file.close()
        output=output.replace('\n', ' . ').replace('\r', ' ')
        output=output.split(" ")
        output=" ".join(output)
        #print(output)
        if output.find("corresponding"):
            pos= output.find("corresponding")
            print(pos)
            for author in authorList:
                if author in strings[pos-30:pos+30]:
                    corre.append(author)
        return corre
    
    def symbolJudgement(self,resourceId):
        file = open('txt/'+str(resourceId)+'.txt',encoding="utf-8")
        strings=file.read()
        strings=strings[:3000]
        #print(strings)
        if strings.find("equally"):
            pos= strings.find("equally")
            #print(pos)
            for star in self.STARS:
                if star in strings[pos-50:pos+50]:
                    return 1 #star represent equall 
        if strings.find("Corresponding"):
            pos= strings.find("Corresponding")
            for star in self.STARS:
                if star in strings[pos-50:pos+50]:
                    return 2 #star represent correspinding 
        if "Alphabetical" in strings:
            return 3
        return 0
    
    def matchAuthor(self,roleList,authorList):
        author_role=[]
        for role in roleList:
            highest=0
            index=0
            for i in range(len(authorList)):
                if jaro(role, authorList[i])>highest:
                    index=i
                    highest=jaro(role, authorList[i])
            #print(highest,authorList[index])
            if highest>0.7:
                author_role.append(authorList[index])
        return author_role
    
    def specialAuthors(self,output,authorList,resourceId):
        starList=[]
        crossList=[]
        for i in range(len(output)):
            for star in self.STARS:
                if star in output[i]:
                    starList.append(" ".join(output[i-2:i+1]))
            for cross in self.CROSS:
                if cross in output[i]:
                    crossList.append(" ".join(output[i-2:i+1]))
        judge=self.symbolJudgement(resourceId)
        #print(judge)
        if judge==0 or judge==1:
            star=self.matchAuthor(starList,authorList)
            corre=self.matchAuthor(crossList,authorList) 
        elif judge==2:
            star=self.matchAuthor(starList,authorList)
            corre=copy.copy(star)
            star=[]
        elif judge==3:
            star=[]
            corre=[]
        #print(star)
        return star,corre

    def sequenceExtratcor(self,output,authorList,parameter=0):
        author_sequence={}
        author_sequence_list=[]
        authorListCopy=copy.copy(authorList)
        num=1
        for i in range(len(output)):
            for name in authorListCopy:
                if output[i] in name and len(output[i])>=2 and self.detectCapitalUse(output[i]):
                    author_sequence[name]=num
                    author_sequence_list.append(name)
                    num+=1
                    authorListCopy.remove(name)
                    break
        if len(author_sequence_list)==len(authorList):
            authorList=author_sequence_list
        if parameter==0:
            return author_sequence
        else:
            return authorList
    
    def main(self,resourceId,authorList,authorPaper,authorCitation,authorID):
        extractor=AuthorInfoExtract()
        
        output=extractor.locateContext(resourceId)
        #print(output)
        author_sequence=extractor.sequenceExtratcor(output,authorList)
        print(author_sequence)
        star,corre=extractor.specialAuthors(output,authorList,resourceId)
        output2=extractor.acknowledgementJudgement(resourceId,authorList,corre)
       # print(output2)
        #print(star)
#         try:
        df=pd.DataFrame.from_dict(author_sequence,orient='index',columns=['sequence'])
        df=df.reset_index().rename(columns={'index':'name'})
        df['star']=0
        for index, row in df.iterrows():
            for author in star:
                if row["name"]==author:
                    df.loc[index,"star"] = 1
        df['corre']=0
        for index, row in df.iterrows():
            for author in corre:
                #print(row["name"],author,index)
                if row["name"]==author:
                    df.loc[index,"corre"] = 1
        df['paperCount']=0
        for index, row in df.iterrows():
            for k,v in authorPaper.items():
                #print(row["name"],author,index)
                if row["name"]==k:
                    df.loc[index,"paperCount"] = v

        df['citationCount']=0
        for index, row in df.iterrows():
            for k,v in authorCitation.items():
                #print(row["name"],author,index)
                if row["name"]==k:
                    df.loc[index,"citationCount"] = v
        df['authorID']=0
        for index, row in df.iterrows():
            for k,v in authorID.items():
                #print(row["name"],author,index)
                if row["name"]==k:
                    df.loc[index,"authorID"] = v
#         except:
#             print("error occured!")
#             df=pd.DataFrame(columns=['name', 'sequence', 'star', 'corre'])
        return df
    
# extractor=AuthorInfoExtract()
# annotation=extractor.main()
# annotation

# %%
# def softmax(x):
#     return np.exp(x)/np.sum(np.exp(x),axis=0)
def lookup_id(author,df):
    author_id=""
#     for index, row in df.iterrows():
    for index, row in df.iterrows():
        #print(index)
        #print(k1,v2)
        if author==row["name"]:
            author_id=(df.at[index,"authorID"])
            break
    return author_id
def roleGenerator(df,resourceId):
    ROLES=['Writing_Draft','Writing_Review_Editing','Supervision','Resource','Software']
    LEVELS=[10,50,100,200,1000,3000,5000,10000]
    df_role = pd.DataFrame(0.0, index=df.name, columns=ROLES)
    #sieve1:Sequence
    for index in range(len(df)):
        df_role.loc[df.name[index],"Writing_Draft"] =1/df.sequence[index]
        df_role.loc[df.name[index],"Writing_Review_Editing"] =(df.sequence[index]/len(df.sequence))-0.1
    #Last author is likely to be supervisioner
    
    #sieve2:Annotation
    for index in range(len(df)):
        if df.star[index]==1:
            df_role.loc[df.name[index],"Writing_Draft"] +=1
        if (len(df.star[df.star>0]))<=2:
            if df.corre[index]==1:
                df_role.loc[df.name[index],"Writing_Review_Editing"] +=1
                df_role.loc[df.name[index],"Supervision"] +=0.5
                #df_role.loc[df.name[index],"Supervision"] +=0.5
            
    #sieve3:Citation and Paper
    for index in range(len(df)):
        df_role.Supervision[index]=df.citationCount[index]*0.2/sum(df.citationCount)+df.paperCount[index]*0.8/sum(df.paperCount)
#         print(v)
    for index in range(len(df)):
        num=0.0
        for level in LEVELS:
            if df.citationCount[index]>level:
                num+=0.125
            if df.paperCount[index]>level:
                num+=0.125
        df_role.Resource[index]=num
        df_role.Writing_Review_Editing[index]+=num/5
    print(df_role) 
    author_contribution={}
    paper_contribution={}
    contribution_role={}
    
    result_1=[]
    result_2=[]
    result_3=[]
#     try:
    supervisionMax=max(df_role.Supervision)
   # print(supervisionMax)
    for index in range(len(df_role)):
        try:
            author_id=lookup_id(df.name[index],df)
            if df_role.loc[df.name[index],"Writing_Draft"]>=1:
                contribution_id=resourceId+"_"+author_id+"_Writing_Draft"
                author_contribution[contribution_id] =author_id     #isContributionByAuthor
                paper_contribution[resourceId]=contribution_id    #isContributionToPaper
                contribution_role[contribution_id]="Writing_Draft"
            if df_role.loc[df.name[index],"Writing_Review_Editing"]>=1:
                contribution_id=resourceId+"_"+author_id+"_Writing_Review_Editing"
                author_contribution[contribution_id] =author_id     #isContributionByAuthor
                paper_contribution[resourceId]=contribution_id    #isContributionToPaper
                contribution_role[contribution_id]="Writing_Review_Editing"
            if df_role.loc[df.name[index],"Resource"]>=1:
                contribution_id=resourceId+"_"+author_id+"_Resource"
                author_contribution[contribution_id] =author_id     #isContributionByAuthor
                paper_contribution[resourceId]=contribution_id    #isContributionToPaper
                contribution_role[contribution_id]="Resource"
            if df_role.loc[df.name[index],"Supervision"]==supervisionMax:
                contribution_id=resourceId+"_"+author_id+"_Supervision"
                author_contribution[contribution_id] =author_id     #isContributionByAuthor
                paper_contribution[resourceId]=contribution_id    #isContributionToPaper
                contribution_role[contribution_id]="Supervision"
            if author_contribution!={}:
                result_1.append(author_contribution)
                result_2.append(paper_contribution)
                result_3.append(contribution_role)
        except:
            print("fail to generate roles")
#def roleClassification(df):
    #print(df_role)
    return result_1,result_2,result_3
#     for index, row in df_role.iterrows():
#         for k,v in df.sequence
#             #print(row["name"],author,index)
#             if row["name"]==k:
#                 df_role.loc[index,"citationCount"] = v
#roleGenerator(annotation)

# %% [markdown]
# From the generated txt file, first we try to extract the email address by using regular experssion
# ### TODO: Special format such as {aaa, bbb, ccc}@xxx.com

# %% [markdown]
# Secondly we match the author name list with the email list by token matching method (Levenshtein)
# ### TODO: HOW can we access author list?

# %%
from Levenshtein import *
import re
class EmailInfoExtract():
    '''
    This class is used to extract email address and match with the authors
    The result is orgnized as a list containing dictionaries
    '''
    def __init__(self):
        self.name_email={}
        self.result=[]
    def get_alpha_str(self,s):
        result = ''.join([x for x in s if x.isalpha()])
        return result

    def email_extraction(self,file_name):
        file = open('txt/'+str(file_name)+'.txt',encoding="utf-8")
        strings=file.read()
        #First page's txt
        strings=strings[:3000]
        matches = []
        matchesGroup=[]
        #1. singular email address
        emailRegex = re.compile(r'''(
            [a-zA-Z0-9._%+-]+      # username
            @+                     # @ symbol

           [a-zA-Z0-9_-]+
           (\.[a-zA-Z0-9_-]+)+
            )''', re.VERBOSE)
        # using RE to match all the patterns in the txt
        for groups in emailRegex.findall(strings):
            matches.append(groups[0])

        list2 = matches
        list_nums = len(list2)
        emailList=[]
        for line in range(list_nums):
            emailList.append(list2[line])
        #2. grouped email list {}
        emailRegex2 = re.compile(r'''(
        \{(.+?)\}+
        @                      # @ symbol

        [a-zA-Z0-9.-]+        # domain name

        (\.[a-zA-Z]{1,4}){1,2} # dot-something
        )''', re.VERBOSE)
        for groups in emailRegex2.findall(strings):
            #print(groups)
            matchesGroup.append(groups[0])
        list3 = matchesGroup
        if len(matchesGroup)>0:
            for gp in list3:
                stringGroup = gp
                index=stringGroup.find("@", 0)
                prefix=stringGroup[:index]
                suffix=stringGroup[index:]
                tempNameList=prefix[1:-1].split(",");
                for name in tempNameList:
                    emailList.append(name+suffix)
                #print(emailList)
        #3. convert to sequenced list if possible 
        sequencedList=[]
        temp_dict={}
        for mail in emailList:
            index=mail.find("@",0)
            prefix=mail[:index]
            email_index=strings.find(prefix)
            temp_dict[mail]=email_index
        sort_idct=sorted(temp_dict.items(),key = lambda x:x[1],reverse = False)
        for k,v in sort_idct:
            sequencedList.append(k)
        #print((sequencedList))

        if len(sequencedList)==len(emailList):
            return sequencedList
        else:
            return emailList
    def lookup_id(self,author,df):
        author_id=""
    #     for index, row in df.iterrows():
        for index, row in df.iterrows():
            #print(index)
            #print(k1,v2)
            if author==row["name"]:
                author_id=(df.at[index,"authorID"])
                break
        return author_id

    def order_matching(self,nameList, emailList):   
        print("ORDER MATCHING")
        for i in range(len(nameList)):
            pat = re.compile(''+'(.*?)'+'@', re.S)
            email = pat.findall(emailList[i])
            email=self.get_alpha_str(email)
            name=nameList[i]
            if (jaro(name, str(email)))<0.4:
                return False
            else:
                self.name_email[name]=email
        return name_email

    #2.No macthes, need to group based on experience and naive approach
    def naive_matching(self,nameList, emailList):
        print("NAIVE MATCHING")
        for name in nameList:
            highest=0
            index=0
            for i in range(len(emailList)):
                #name=filter(lambda x: x.isalpha(), name)
                #using re to extract the first part of email
                pat = re.compile(''+'(.*?)'+'@', re.S)
                email = pat.findall(emailList[i])
                email=self.get_alpha_str(email)
                #print(str(email))
                #print(jaro(name, str(email)))
                #using jaro to calculate the similarity between two strings
                if jaro(name, str(email))>highest:
                    index=i
                    highest=jaro(name, str(email))
            #set pair with the highest score
                    #print(name,highest,emailList[i])
            #self.name_email[name]=emailList[index]
            #If very sure, remove it from the list to reduce the uncertainty for other pairs
            if highest>=0.6:
                self.name_email[name]=emailList[index]
                emailList.remove(emailList[index])
            if highest<=0.4:
                self.name_email[name]=''
        for email in emailList:
            if email not in self.name_email:
                for name in self.name_email:
                    if self.name_email[name]=='':
                        self.name_email[name]=email
                        #print(jaro(name, str(email)))
        return self.name_email
    
    def main(self,resourceId,authorList,df):
        extractor=AuthorInfoExtract()
        output=extractor.locateContext(resourceId)
        nameList=extractor.sequenceExtratcor(output,authorList,1)
        emailList=self.email_extraction(resourceId)
        #print(emailList)
        if len(emailList)==0:
            return
        name_email={}
        #1.If sequenced list and length matches
        if len(nameList)==len(emailList):
            self.name_email=self.order_matching(nameList, emailList)
        if not name_email:
            self.name_email={}
            self.name_email=self.naive_matching(nameList, emailList)
        
        for k,v in self.name_email.items():
            author_id=self.lookup_id(k,df)
            #print(author_id)
            temp={}
            temp[author_id]=v
            self.result.append(temp)
        return self.result
        #return self.name_email
    
# emailExtractor=EmailInfoExtract()
# name_email=emailExtractor.main()

# name_email

# %%
from rdflib import Graph, ConjunctiveGraph, Literal, BNode, Namespace, RDF, URIRef,RDFS
from rdflib.namespace import DC, FOAF
from owlrl import DeductiveClosure, RDFS_Semantics
import pprint
import json
def create_triple_email(totalList):
    g = Graph()
    for lst in totalList:
        if lst!=None:
            for dic in lst:
                for author_id,v1 in dic.items():  
                    #author = BNode()
#                     print(k1,v1)
#                     author_id=lookup_id(k1,df)
#                     print(author_id)
                    author = URIRef("http://www.scoaring.com/ontology#%s")%author_id
                    #print(author)
                    g.add((author, FOAF.mbox, Literal(v1)))
    print(len(g))
    print(g.serialize(format='turtle').decode())
    g.serialize(destination='email_sequential.txt', format='turtle')
    
def create_triple_role(totalList,num):
    n = Namespace("http://www.scoaring.com/ontology")
    g = Graph()
    for lst in totalList:
        if lst!=None:
            for dic in lst:
                if num==1: #Contribution_Author
                    for contribution_id,author_id in dic.items():
                        #contribution = BNode()
                        contribution = URIRef("http://www.scoaring.com/ontology#%s")%contribution_id
                        typeClass=URIRef("http://www.scoaring.com/ontology#contribution")
                        predict= URIRef("http://www.scoaring.com/ontology#isContributionByAuthor")#refersTo
                        author = URIRef("http://www.scoaring.com/ontology#%s")%author_id
                        g.add((contribution, RDF.type, typeClass))
                        g.add((contribution, predict, author))
                if num==2: #Paper_Contribution
                    for paper_id,contribution_id in dic.items():
                        paper = URIRef("http://www.scoaring.com/ontology#%s")%paper_id
                        contribution = URIRef("http://www.scoaring.com/ontology#%s")%contribution_id
                        predict= URIRef("http://www.scoaring.com/ontology#isContributionToPaper")#refersTo
                        g.add((paper, predict, contribution))
                if num==3: #Contribution_role
                    for contribution_id,role in dic.items():
                        contribution = URIRef("http://www.scoaring.com/ontology#%s")%contribution_id
                        predict = URIRef("http://www.scoaring.com/ontology#role")
                        g.add((contribution, predict, Literal(role)))
            #####IF more roles add here#####
    g.serialize(destination=('role_sequential_%d.txt')%num, format='turtle')
#create_triple_email("email_output3")

# %%
import json
def main():
    processing=Processing()
    processing.NUM=2000#All papers
    email=[]
    role_1=[]#Contribution_Author
    role_2=[]#Paper_Contribution
    role_3=[]#Contribution_role
    for i in range(processing.NUM):
        try:
            resourceId,authorList,authorPaper,authorCitation,authorID=processing.main(i)
            print(authorList)
            extractor=AuthorInfoExtract()
            annotation=extractor.main(resourceId,authorList,authorPaper,authorCitation,authorID)
            print(annotation)
            author_role,paper_role,contribution_role=roleGenerator(annotation,resourceId)
            role_1.append(author_role)
            role_2.append(paper_role)
            role_3.append(contribution_role)
            #print(author_role)
            emailExtractor=EmailInfoExtract()
            name_email=emailExtractor.main(resourceId,authorList,annotation)
            email.append(name_email)
        except:
            continue
    create_triple_role(role_1,1)
    create_triple_role(role_2,2)
    create_triple_role(role_3,3)
    json1 = json.dumps(role_1)
    json2 = json.dumps(role_2)
    json3 = json.dumps(role_3)
    with open("json_1.txt", 'w') as f:
        json.dump(json1, f)
    with open("json_2.txt", 'w') as f:
        json.dump(json2, f)
    with open("json_3.txt", 'w') as f:
        json.dump(json3, f)
    create_triple_email(email)
main()
# Out:
# P1156351 http://arxiv.org/pdf/1710.01269v1.pdf
# ['Christian S. Perone', 'Evan Calabrese', 'Julien Cohen-Adad']
# {'Christian S. Perone': 1, 'Evan Calabrese': 2, 'Julien Cohen-Adad': 3}
# -1
#                   name  sequence  star  corre  paperCount  citationCount  \
# 0  Christian S. Perone         1     0      0          -1             -1
# 1       Evan Calabrese         2     0      0          31            413
# 2    Julien Cohen-Adad         3     0      0         128           2664
#
#   authorID
# 0   A25789
# 1   A40972
# 2   A72276
#                      Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Christian S. Perone       1.000000                0.233333    -0.005128
# Evan Calabrese            0.500000                0.691667     0.183815
# Julien Cohen-Adad         0.333333                1.100000     0.821313
#
#                      Resource  Software
# name
# Christian S. Perone     0.000       0.0
# Evan Calabrese          0.625       0.0
# Julien Cohen-Adad       1.000       0.0
# P1156365 http://arxiv.org/pdf/1803.03095v1.pdf
# ['Andrew D. Bagdanov', 'Joost van de Weijer', 'Xialei Liu']
# {'Xialei Liu': 1, 'Joost van de Weijer': 2, 'Andrew D. Bagdanov': 3}
# -1
#                   name  sequence  star  corre  paperCount  citationCount  \
# 0           Xialei Liu         1     0      0           5              2
# 1  Joost van de Weijer         2     0      0         106           2699
# 2   Andrew D. Bagdanov         3     0      0          -1             -1
#
#   authorID
# 0  A150673
# 1   A70040
# 2   A10097
#                      Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Xialei Liu                1.000000                0.233333     0.036512
# Joost van de Weijer       0.500000                0.766667     0.970835
# Andrew D. Bagdanov        0.333333                0.900000    -0.007347
#
#                      Resource  Software
# name
# Xialei Liu                0.0       0.0
# Joost van de Weijer       1.0       0.0
# Andrew D. Bagdanov        0.0       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1156386 http://arxiv.org/pdf/1706.03686v3.pdf
# ['Haiyan Yao', 'Kang Han', 'Li Hou', 'Wanggen Wan']
# {'Kang Han': 1, 'Wanggen Wan': 2, 'Haiyan Yao': 3, 'Li Hou': 4}
# -1
#           name  sequence  star  corre  paperCount  citationCount authorID
# 0     Kang Han         1     0      0           3              1   A74608
# 1  Wanggen Wan         2     0      0         176            222  A147707
# 2   Haiyan Yao         3     0      0           4              1   A51241
# 3       Li Hou         4     0      0           9             15   A81804
#              Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Kang Han          1.000000                   0.150     0.013337     0.000
# Wanggen Wan       0.500000                   0.575     0.919107     0.875
# Haiyan Yao        0.333333                   0.650     0.017503     0.000
# Li Hou            0.250000                   0.925     0.050052     0.125
#
#              Software
# name
# Kang Han          0.0
# Wanggen Wan       0.0
# Haiyan Yao        0.0
# Li Hou            0.0
# NAIVE MATCHING
# P1156541 https://arxiv.org/pdf/1806.06371v2.pdf
# ['Iryna Gurevych', 'Lisa Beinborn', 'Teresa Botschen']
# {'Lisa Beinborn': 1, 'Teresa Botschen': 2, 'Iryna Gurevych': 3}
# -1
#               name  sequence  star  corre  paperCount  citationCount authorID
# 0    Lisa Beinborn         1     1      0           9             30   A83236
# 1  Teresa Botschen         2     1      0           6              1  A139180
# 2   Iryna Gurevych         3     0      0         329           4103   A58941
#                  Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Lisa Beinborn         2.000000                0.258333     0.022382     0.125
# Teresa Botschen       1.500000                0.566667     0.014002     0.000
# Iryna Gurevych        0.333333                1.150000     0.963617     1.250
#
#                  Software
# name
# Lisa Beinborn         0.0
# Teresa Botschen       0.0
# Iryna Gurevych        0.0
# P1156614 http://arxiv.org/pdf/1709.04496v2.pdf
# ['Christian F. Baumgartner', 'Ender Konukoglu', 'Lisa M. Koch', 'Marc Pollefeys']
# {'Christian F. Baumgartner': 1, 'Lisa M. Koch': 2, 'Marc Pollefeys': 3, 'Ender Konukoglu': 4}
# -1
#                        name  sequence  star  corre  paperCount  citationCount  \
# 0  Christian F. Baumgartner         1     0      0          -1             -1
# 1              Lisa M. Koch         2     0      0          -1             -1
# 2            Marc Pollefeys         3     0      0         477          15584
# 3           Ender Konukoglu         4     0      0         107           2846
#
#   authorID
# 0   A25588
# 1   A83264
# 2   A87950
# 3   A39419
#                           Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Christian F. Baumgartner       1.000000                    0.15    -0.001385
# Lisa M. Koch                   0.500000                    0.40    -0.001385
# Marc Pollefeys                 0.333333                    0.95     0.824804
# Ender Konukoglu                0.250000                    1.10     0.177967
#
#                           Resource  Software
# name
# Christian F. Baumgartner       0.0       0.0
# Lisa M. Koch                   0.0       0.0
# Marc Pollefeys                 1.5       0.0
# Ender Konukoglu                1.0       0.0
# P1156706 http://arxiv.org/pdf/1507.02159v1.pdf
# ['Limin Wang', 'Yu Qiao', 'Yuanjun Xiong', 'Zhe Wang']
# {'Limin Wang': 1, 'Yuanjun Xiong': 2, 'Zhe Wang': 3, 'Yu Qiao': 4}
# -1
#             name  sequence  star  corre  paperCount  citationCount authorID
# 0     Limin Wang         1     0      0          37           1748   A82544
# 1  Yuanjun Xiong         2     0      0          11            534  A159123
# 2       Zhe Wang         3     0      0           6              0  A162443
# 3        Yu Qiao         4     0      0         162           3591  A158698
#                Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Limin Wang          1.000000                   0.300     0.196564     0.750
# Yuanjun Xiong       0.500000                   0.525     0.058926     0.625
# Zhe Wang            0.333333                   0.650     0.022222     0.000
# Yu Qiao             0.250000                   1.125     0.722288     1.125
#
#                Software
# name
# Limin Wang          0.0
# Yuanjun Xiong       0.0
# Zhe Wang            0.0
# Yu Qiao             0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1156739 http://arxiv.org/pdf/1809.04212v2.pdf
# ['Chen Chen', 'Jiayi Ma', 'Junjun Jiang', 'Xianming Liu', 'Zheng Wang']
# {'Junjun Jiang': 1, 'Jiayi Ma': 2, 'Zheng Wang': 3, 'Chen Chen': 4, 'Xianming Liu': 5}
# -1
#            name  sequence  star  corre  paperCount  citationCount authorID
# 0  Junjun Jiang         1     0      0          86            855   A72921
# 1      Jiayi Ma         2     0      0          98           1526   A66011
# 2    Zheng Wang         3     0      0          72            733  A162635
# 3     Chen Chen         4     0      0         101           1497   A23841
# 4  Xianming Liu         5     0      0         113            713  A151007
#               Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Junjun Jiang       1.000000                   0.250     0.178502     0.750
# Jiayi Ma           0.500000                   0.475     0.224134     0.875
# Zheng Wang         0.333333                   0.650     0.150089     0.750
# Chen Chen          0.250000                   0.900     0.228151     1.000
# Xianming Liu       0.200000                   1.075     0.219125     0.875
#
#               Software
# name
# Junjun Jiang       0.0
# Jiayi Ma           0.0
# Zheng Wang         0.0
# Chen Chen          0.0
# Xianming Liu       0.0
# NAIVE MATCHING
# P1156918 http://arxiv.org/pdf/1810.12546v1.pdf
# ['Biao Zhang', 'Deyi Xiong', 'Huiji Zhang', 'Jinsong Su', 'Qian Lin']
# {'Biao Zhang': 1, 'Deyi Xiong': 2, 'Jinsong Su': 3, 'Qian Lin': 4, 'Huiji Zhang': 5}
# -1
#           name  sequence  star  corre  paperCount  citationCount authorID
# 0   Biao Zhang         1     0      0          20             84   A18523
# 1   Deyi Xiong         2     0      0          42            834   A34110
# 2   Jinsong Su         3     0      0          53            161   A67370
# 3     Qian Lin         4     0      0           2              0  A113878
# 4  Huiji Zhang         5     0      0          -1             -1   A56601
#              Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Biao Zhang        1.000000                   0.175     0.153515     0.375
# Deyi Xiong        0.500000                   0.425     0.444386     0.625
# Jinsong Su        0.333333                   0.625     0.395387     0.625
# Qian Lin          0.250000                   0.700     0.013793     0.000
# Huiji Zhang       0.200000                   0.900    -0.007082     0.000
#
#              Software
# name
# Biao Zhang        0.0
# Deyi Xiong        0.0
# Jinsong Su        0.0
# Qian Lin          0.0
# Huiji Zhang       0.0
# NAIVE MATCHING
# P1157014 http://arxiv.org/pdf/1610.09491v1.pdf
# ['András György', 'Csaba Szepesvári', 'Kiarash Shaloudegi', 'Wilsun Xu']
# {'Kiarash Shaloudegi': 1, 'András György': 2, 'Csaba Szepesvári': 3, 'Wilsun Xu': 4}
# -1
#                  name  sequence  star  corre  paperCount  citationCount  \
# 0  Kiarash Shaloudegi         1     0      0           3              5
# 1       András György         2     0      0          -1             -1
# 2    Csaba Szepesvári         3     0      0          -1             -1
# 3           Wilsun Xu         4     0      0         294           5359
#
#   authorID
# 0   A77481
# 1   A10692
# 2   A28673
# 3  A149977
#                     Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Kiarash Shaloudegi       1.000000                   0.150     0.008322
# András György            0.500000                   0.400    -0.002749
# Csaba Szepesvári         0.333333                   0.650    -0.002749
# Wilsun Xu                0.250000                   1.175     0.997176
#
#                     Resource  Software
# name
# Kiarash Shaloudegi     0.000       0.0
# András György          0.000       0.0
# Csaba Szepesvári       0.000       0.0
# Wilsun Xu              1.375       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157079 http://arxiv.org/pdf/1705.03311v2.pdf
# ['Florian Kleber', 'Markus Diem', 'Roger Labahn', 'Stefan Fiel', 'Tobias Grüning']
# {'Tobias Grüning': 1, 'Roger Labahn': 2, 'Markus Diem': 3, 'Florian Kleber': 4, 'Stefan Fiel': 5}
# -1
#              name  sequence  star  corre  paperCount  citationCount authorID
# 0  Tobias Grüning         1     0      0          -1             -1  A141909
# 1    Roger Labahn         2     0      0          16             66  A119997
# 2     Markus Diem         3     0      0          47            256   A90186
# 3  Florian Kleber         4     0      0          40            187   A43829
# 4     Stefan Fiel         5     0      0          18            162  A134065
#                 Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Tobias Grüning       1.000000                   0.100    -0.006965     0.000
# Roger Labahn         0.500000                   0.375     0.126368     0.375
# Markus Diem          0.333333                   0.625     0.389751     0.625
# Florian Kleber       0.250000                   0.800     0.322488     0.500
# Stefan Fiel          0.200000                   1.000     0.168358     0.500
#
#                 Software
# name
# Tobias Grüning       0.0
# Roger Labahn         0.0
# Markus Diem          0.0
# Florian Kleber       0.0
# Stefan Fiel          0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157109 http://arxiv.org/pdf/1704.06743v3.pdf
# ['Aditya Krishna Menon', 'Raghavendra Chalapathy', 'Sanjay Chawla']
# {'Raghavendra Chalapathy': 1, 'Aditya Krishna Menon': 2, 'Sanjay Chawla': 3}
# -1
#                      name  sequence  star  corre  paperCount  citationCount  \
# 0  Raghavendra Chalapathy         1     0      0           2              5
# 1    Aditya Krishna Menon         2     0      0          60            826
# 2           Sanjay Chawla         3     0      0         155           2678
#
#   authorID
# 0  A115739
# 1   A02341
# 2  A124937
#                         Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Raghavendra Chalapathy       1.000000                0.233333     0.007658
# Aditya Krishna Menon         0.500000                0.716667     0.268277
# Sanjay Chawla                0.333333                1.100000     0.724065
#
#                         Resource  Software
# name
# Raghavendra Chalapathy      0.00       0.0
# Aditya Krishna Menon        0.75       0.0
# Sanjay Chawla               1.00       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157113 http://arxiv.org/pdf/1708.01101v1.pdf
# ['Hongsheng Li', 'Shuang Li', 'Wanli Ouyang', 'Wei Yang', 'Xiaogang Wang']
# {'Wei Yang': 1, 'Shuang Li': 2, 'Wanli Ouyang': 3, 'Hongsheng Li': 4, 'Xiaogang Wang': 5}
# -1
#             name  sequence  star  corre  paperCount  citationCount authorID
# 0       Wei Yang         1     0      0         120            600  A148032
# 1      Shuang Li         2     0      0          13             84  A130561
# 2   Wanli Ouyang         3     0      0          91           3357  A147743
# 3   Hongsheng Li         4     0      0          84           2263   A55398
# 4  Xiaogang Wang         5     0      0         262          14893  A151371
#                Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Wei Yang            1.000000                   0.275     0.174082     0.875
# Shuang Li           0.500000                   0.375     0.019038     0.375
# Wanli Ouyang        0.333333                   0.700     0.159394     1.000
# Hongsheng Li        0.250000                   0.875     0.139247     0.875
# Xiaogang Wang       0.200000                   1.200     0.508239     1.500
#
#                Software
# name
# Wei Yang            0.0
# Shuang Li           0.0
# Wanli Ouyang        0.0
# Hongsheng Li        0.0
# Xiaogang Wang       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157207 http://arxiv.org/pdf/1805.09112v2.pdf
# ['Gary Bécigneul', 'Octavian-Eugen Ganea', 'Thomas Hofmann']
# {'Gary Bécigneul': 1, 'Thomas Hofmann': 2}
# -1
#              name  sequence  star  corre  paperCount  citationCount authorID
# 0  Gary Bécigneul         1     1      0          -1             -1   A46282
# 1  Thomas Hofmann         2     0      0          31            288  A140068
#                 Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Gary Bécigneul            2.0                   0.400    -0.027364     0.000
# Thomas Hofmann            0.5                   1.025     1.027364     0.625
#
#                 Software
# name
# Gary Bécigneul       0.0
# Thomas Hofmann       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157350 http://arxiv.org/pdf/1712.04577v2.pdf
# ['Anima Anandkumar', 'Ashish Khetan', 'Zachary C. Lipton']
# {'Ashish Khetan': 1, 'Zachary C. Lipton': 2, 'Anima Anandkumar': 3}
# -1
#                 name  sequence  star  corre  paperCount  citationCount  \
# 0      Ashish Khetan         1     0      0          13             39
# 1  Zachary C. Lipton         2     0      0          -1             -1
# 2   Anima Anandkumar         3     0      0          27            329
#
#   authorID
# 0   A14689
# 1  A161421
# 2   A11239
#                    Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Ashish Khetan           1.000000                0.283333     0.287920
# Zachary C. Lipton       0.500000                0.566667    -0.021058
# Anima Anandkumar        0.333333                1.025000     0.733138
#
#                    Resource  Software
# name
# Ashish Khetan         0.250       0.0
# Zachary C. Lipton     0.000       0.0
# Anima Anandkumar      0.625       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157371 http://arxiv.org/pdf/1710.06564v3.pdf
# ['Hamed Haddadi', 'Mohammad Malekzadeh', 'Richard G. Clegg']
# {'Mohammad Malekzadeh': 1, 'Richard G. Clegg': 2, 'Hamed Haddadi': 3}
# -1
#                   name  sequence  star  corre  paperCount  citationCount  \
# 0  Mohammad Malekzadeh         1     0      0           3              3
# 1     Richard G. Clegg         2     0      0          -1             -1
# 2        Hamed Haddadi         3     0      0          31            319
#
#   authorID
# 0   A99256
# 1  A118368
# 2   A51420
#                      Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Mohammad Malekzadeh       1.000000                0.233333     0.074596
# Richard G. Clegg          0.500000                0.566667    -0.024865
# Hamed Haddadi             0.333333                1.025000     0.950269
#
#                      Resource  Software
# name
# Mohammad Malekzadeh     0.000       0.0
# Richard G. Clegg        0.000       0.0
# Hamed Haddadi           0.625       0.0
# NAIVE MATCHING
# P1157382 http://arxiv.org/pdf/1508.03826v1.pdf
# ['Chunyan Miao', 'Jun Zhu', 'Shaohua Li']
# {'Shaohua Li': 1, 'Jun Zhu': 2, 'Chunyan Miao': 3}
# -1
#            name  sequence  star  corre  paperCount  citationCount authorID
# 0    Shaohua Li         1     0      0           1              0  A128483
# 1       Jun Zhu         2     0      0         178           2526   A72579
# 2  Chunyan Miao         3     0      0           1              0   A27265
#               Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Shaohua Li         1.000000                0.233333     0.004444       0.0
# Jun Zhu            0.500000                0.766667     0.991111       1.0
# Chunyan Miao       0.333333                0.900000     0.004444       0.0
#
#               Software
# name
# Shaohua Li         0.0
# Jun Zhu            0.0
# Chunyan Miao       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157414 http://arxiv.org/pdf/1610.04325v4.pdf
# ['Byoung-Tak Zhang', 'Jeonghee Kim', 'Jin-Hwa Kim', 'Jung-Woo Ha', 'Kyoung-Woon On', 'Woosang Lim']
# {'Jeonghee Kim': 1, 'Kyoung-Woon On': 2, 'Woosang Lim': 3, 'Jin-Hwa Kim': 4, 'Jung-Woo Ha': 5, 'Byoung-Tak Zhang': 6}
# -1
#                name  sequence  star  corre  paperCount  citationCount authorID
# 0      Jeonghee Kim         1     0      0           6            107   A63978
# 1    Kyoung-Woon On         2     0      0          -1             -1   A79610
# 2       Woosang Lim         3     0      0           2              9  A150300
# 3       Jin-Hwa Kim         4     0      0          11            116   A66595
# 4       Jung-Woo Ha         5     0      0          29            189   A72742
# 5  Byoung-Tak Zhang         6     0      0         386           5330   A20969
#                   Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Jeonghee Kim           1.000000                0.141667     0.014807
# Kyoung-Woon On         0.500000                0.233333    -0.001882
# Woosang Lim            0.333333                0.400000     0.004008
# Jin-Hwa Kim            0.250000                0.666667     0.024358
# Jung-Woo Ha            0.200000                0.833333     0.060154
# Byoung-Tak Zhang       0.166667                1.175000     0.898555
#
#                   Resource  Software
# name
# Jeonghee Kim         0.375       0.0
# Kyoung-Woon On       0.000       0.0
# Woosang Lim          0.000       0.0
# Jin-Hwa Kim          0.500       0.0
# Jung-Woo Ha          0.500       0.0
# Byoung-Tak Zhang     1.375       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157455 http://arxiv.org/pdf/1606.00850v3.pdf
# ['Benyuan Sun', 'Tianfu Wu', 'Yizhou Wang', 'Yunzhu Li']
# {'Yunzhu Li': 1, 'Benyuan Sun': 2, 'Tianfu Wu': 3, 'Yizhou Wang': 4}
# -1
#           name  sequence  star  corre  paperCount  citationCount authorID
# 0    Yunzhu Li         1     1      0           2             24  A160577
# 1  Benyuan Sun         2     0      0           1             32   A17964
# 2    Tianfu Wu         3     0      0          27            363  A140751
# 3  Yizhou Wang         4     0      0         114           1614  A157467
#              Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Yunzhu Li         2.000000                   0.175     0.013472     0.125
# Benyuan Sun       0.500000                   0.425     0.008704     0.125
# Tianfu Wu         0.333333                   0.775     0.185711     0.625
# Yizhou Wang       0.250000                   1.100     0.792113     1.000
#
#              Software
# name
# Yunzhu Li         0.0
# Benyuan Sun       0.0
# Tianfu Wu         0.0
# Yizhou Wang       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157587 http://arxiv.org/pdf/1505.00290v2.pdf
# ['Anup Rao', 'Daniel A. Spielman', 'Rasmus Kyng', 'Sushant Sachdeva']
# {'Rasmus Kyng': 1, 'Anup Rao': 2, 'Sushant Sachdeva': 3, 'Daniel A. Spielman': 4}
# -1
#                  name  sequence  star  corre  paperCount  citationCount  \
# 0         Rasmus Kyng         1     0      0          11             74
# 1            Anup Rao         2     0      0          69           1468
# 2    Sushant Sachdeva         3     0      0          15             63
# 3  Daniel A. Spielman         4     0      0          -1             -1
#
#   authorID
# 0  A116986
# 1   A12978
# 2  A136657
# 3   A30005
#                     Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Rasmus Kyng              1.000000                   0.225     0.102844
# Anup Rao                 0.500000                   0.575     0.770276
# Sushant Sachdeva         0.333333                   0.725     0.135515
# Daniel A. Spielman       0.250000                   0.900    -0.008635
#
#                     Resource  Software
# name
# Rasmus Kyng            0.375       0.0
# Anup Rao               0.875       0.0
# Sushant Sachdeva       0.375       0.0
# Daniel A. Spielman     0.000       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157619 https://www.aclweb.org/anthology/W17-4902.pdf
# ['Eduard Hovy', 'Eric Nyberg', 'Harsh Jhamtani', 'Varun Gangal']
# {}
# -1
# Empty DataFrame
# Columns: [name, sequence, star, corre, paperCount, citationCount, authorID]
# Index: []
# Empty DataFrame
# Columns: [Writing_Draft, Writing_Review_Editing, Supervision, Resource, Software]
# Index: []
# P1157860 http://arxiv.org/pdf/1509.08067v6.pdf
# ['Song-Chun Zhu', 'Tianfu Wu', 'Yang Lu']
# {'Tianfu Wu': 1, 'Yang Lu': 2, 'Song-Chun Zhu': 3}
# -1
#             name  sequence  star  corre  paperCount  citationCount authorID
# 0      Tianfu Wu         1     0      0          27            363  A140751
# 1        Yang Lu         2     0      0          13            122  A154434
# 2  Song-Chun Zhu         3     0      0         338          11353  A132964
#                Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Tianfu Wu           1.000000                0.358333     0.063276     0.625
# Yang Lu             0.500000                0.666667     0.029574     0.500
# Song-Chun Zhu       0.333333                1.200000     0.907150     1.500
#
#                Software
# name
# Tianfu Wu           0.0
# Yang Lu             0.0
# Song-Chun Zhu       0.0
# P1157866 http://arxiv.org/pdf/1704.01047v3.pdf
# ['Ali Osman Ulusoy', 'Andreas Geiger', 'Gernot Riegler', 'Horst Bischof']
# {'Gernot Riegler': 1, 'Ali Osman Ulusoy': 2, 'Horst Bischof': 3, 'Andreas Geiger': 4}
# -1
#                name  sequence  star  corre  paperCount  citationCount authorID
# 0    Gernot Riegler         1     0      0          18            199   A47446
# 1  Ali Osman Ulusoy         2     0      0          14            254   A06773
# 2     Horst Bischof         3     0      0         534          19267   A55644
# 3    Andreas Geiger         4     0      0          88           5297   A09592
#                   Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Gernot Riegler         1.000000                   0.250     0.023609
# Ali Osman Ulusoy       0.500000                   0.525     0.019156
# Horst Bischof          0.333333                   0.950     0.807242
# Andreas Geiger         0.250000                   1.125     0.149992
#
#                   Resource  Software
# name
# Gernot Riegler       0.500       0.0
# Ali Osman Ulusoy     0.625       0.0
# Horst Bischof        1.500       0.0
# Andreas Geiger       1.125       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1157968 https://www.aclweb.org/anthology/W17-5704.pdf
# ['Aizhan Imankulova', 'Mamoru Komachi', 'Takayuki Sato']
# {}
# -1
# Empty DataFrame
# Columns: [name, sequence, star, corre, paperCount, citationCount, authorID]
# Index: []
# Empty DataFrame
# Columns: [Writing_Draft, Writing_Review_Editing, Supervision, Resource, Software]
# Index: []
# P1158261 http://arxiv.org/pdf/1804.06208v2.pdf
# ['Bin Xiao', 'Haiping Wu', 'Yichen Wei']
# {'Bin Xiao': 1, 'Haiping Wu': 2, 'Yichen Wei': 3}
# -1
#          name  sequence  star  corre  paperCount  citationCount authorID
# 0    Bin Xiao         1     1      0           3              9   A18752
# 1  Haiping Wu         2     0      0           1              1   A51142
# 2  Yichen Wei         3     0      0          33           1669  A156204
#             Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Bin Xiao         2.000000                0.233333     0.065937      0.00
# Haiping Wu       0.500000                0.566667     0.021741      0.00
# Yichen Wei       0.333333                1.050000     0.912322      0.75
#
#             Software
# name
# Bin Xiao         0.0
# Haiping Wu       0.0
# Yichen Wei       0.0
# NAIVE MATCHING
# P1158360 https://www.aclweb.org/anthology/C16-1195.pdf
# ['Christian M. Meyer', 'Iryna Gurevych', 'Judith Eckle-Kohler']
# {}
# -1
# Empty DataFrame
# Columns: [name, sequence, star, corre, paperCount, citationCount, authorID]
# Index: []
# Empty DataFrame
# Columns: [Writing_Draft, Writing_Review_Editing, Supervision, Resource, Software]
# Index: []
# P1158733 http://arxiv.org/pdf/1611.03787v1.pdf
# ['Dougal Sutherland', 'Seth Flaxman', 'Yee Whye Teh', 'Yu-Xiang Wang']
# {'Seth Flaxman': 1, 'Dougal Sutherland': 2, 'Yu-Xiang Wang': 3, 'Yee Whye Teh': 4}
# -1
#                 name  sequence  star  corre  paperCount  citationCount  \
# 0       Seth Flaxman         1     0      0          41           6494
# 1  Dougal Sutherland         2     0      0          22            163
# 2      Yu-Xiang Wang         3     0      0          73            454
# 3       Yee Whye Teh         4     0      0         178          13604
#
#   authorID
# 0  A127440
# 1   A36405
# 2  A158908
# 3  A155667
#                    Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Seth Flaxman            1.000000                   0.350     0.167157
# Dougal Sutherland       0.500000                   0.500     0.057625
# Yu-Xiang Wang           0.333333                   0.800     0.190371
# Yee Whye Teh            0.250000                   1.175     0.584848
#
#                    Resource  Software
# name
# Seth Flaxman          1.000       0.0
# Dougal Sutherland     0.500       0.0
# Yu-Xiang Wang         0.750       0.0
# Yee Whye Teh          1.375       0.0
# NAIVE MATCHING
# P1158758 http://arxiv.org/pdf/1805.10407v4.pdf
# ['Neal Jean', 'Sang Michael Xie', 'Stefano Ermon']
# {'Neal Jean': 1, 'Sang Michael Xie': 2, 'Stefano Ermon': 3}
# -1
#                name  sequence  star  corre  paperCount  citationCount authorID
# 0         Neal Jean         1     1      0           6            143  A102845
# 1  Sang Michael Xie         2     1      0           1              0  A124769
# 2     Stefano Ermon         3     0      0         113            755  A134349
#                   Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Neal Jean              2.000000                0.308333     0.071849
# Sang Michael Xie       1.500000                0.566667     0.006667
# Stefano Ermon          0.333333                1.075000     0.921485
#
#                   Resource  Software
# name
# Neal Jean            0.375       0.0
# Sang Michael Xie     0.000       0.0
# Stefano Ermon        0.875       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1158830 http://arxiv.org/pdf/1807.06441v1.pdf
# ['Jan Vanek', 'Jan Zelinka', 'Josef Michalek', 'Josef Psutka']
# {'Jan Vanek': 1, 'Josef Michalek': 2, 'Jan Zelinka': 3, 'Josef Psutka': 4}
# -1
#              name  sequence  star  corre  paperCount  citationCount authorID
# 0       Jan Vanek         1     0      0          -1             -1   A61887
# 1  Josef Michalek         2     0      0           6              3   A70588
# 2     Jan Zelinka         3     0      0          38            105   A61916
# 3    Josef Psutka         4     0      0         139            794   A70594
#                 Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Jan Vanek            1.000000                   0.150    -0.004618     0.000
# Josef Michalek       0.500000                   0.400     0.027040     0.000
# Jan Zelinka          0.333333                   0.750     0.190340     0.500
# Josef Psutka         0.250000                   1.075     0.787238     0.875
#
#                 Software
# name
# Jan Vanek            0.0
# Josef Michalek       0.0
# Jan Zelinka          0.0
# Josef Psutka         0.0
# ORDER MATCHING
# P1158838 http://arxiv.org/pdf/1702.00748v2.pdf
# ['Cyril Becot', 'Gilles Louppe', 'Kyle Cranmer', 'Kyunghyun Cho']
# {'Gilles Louppe': 1, 'Kyunghyun Cho': 2, 'Cyril Becot': 3, 'Kyle Cranmer': 4}
# -1
#             name  sequence  star  corre  paperCount  citationCount authorID
# 0  Gilles Louppe         1     0      0          56            461   A47875
# 1  Kyunghyun Cho         2     0      0         161           9967   A79691
# 2    Cyril Becot         3     0      0          -1             -1   A28790
# 3   Kyle Cranmer         4     0      0          -1             -1   A79507
#                Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Gilles Louppe       1.000000                    0.30     0.217215      0.75
# Kyunghyun Cho       0.500000                    0.65     0.790265      1.25
# Cyril Becot         0.333333                    0.65    -0.003740      0.00
# Kyle Cranmer        0.250000                    0.90    -0.003740      0.00
#
#                Software
# name
# Gilles Louppe       0.0
# Kyunghyun Cho       0.0
# Cyril Becot         0.0
# Kyle Cranmer        0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1158966 http://arxiv.org/pdf/1703.07886v2.pdf
# ['Mehdi Bahri', 'Stefanos Zafeiriou', 'Yannis Panagakis']
# {'Mehdi Bahri': 1, 'Yannis Panagakis': 2, 'Stefanos Zafeiriou': 3}
# -1
#                  name  sequence  star  corre  paperCount  citationCount  \
# 0         Mehdi Bahri         1     0      0           3              2
# 1    Yannis Panagakis         2     0      0          62            454
# 2  Stefanos Zafeiriou         3     0      0         225           4251
#
#   authorID
# 0   A94074
# 1  A154842
# 2  A134447
#                     Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Mehdi Bahri              1.000000                0.233333     0.008361
# Yannis Panagakis         0.500000                0.716667     0.190325
# Stefanos Zafeiriou       0.333333                1.150000     0.801314
#
#                     Resource  Software
# name
# Mehdi Bahri             0.00       0.0
# Yannis Panagakis        0.75       0.0
# Stefanos Zafeiriou      1.25       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1159029 http://arxiv.org/pdf/1607.03975v2.pdf
# ['Eric V. Strobl', 'Peter L. Spirtes', 'Shyam Visweswaran']
# {'Eric V. Strobl': 1, 'Peter L. Spirtes': 2, 'Shyam Visweswaran': 3}
# -1
#                 name  sequence  star  corre  paperCount  citationCount  \
# 0     Eric V. Strobl         1     0      0          -1             -1
# 1   Peter L. Spirtes         2     0      0          -1             -1
# 2  Shyam Visweswaran         3     0      0         100            778
#
#   authorID
# 0   A40064
# 1  A110909
# 2  A131159
#                    Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Eric V. Strobl          1.000000                0.233333    -0.008421
# Peter L. Spirtes        0.500000                0.566667    -0.008421
# Shyam Visweswaran       0.333333                1.050000     1.016842
#
#                    Resource  Software
# name
# Eric V. Strobl         0.00       0.0
# Peter L. Spirtes       0.00       0.0
# Shyam Visweswaran      0.75       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1159134 http://arxiv.org/pdf/1805.11462v1.pdf
# ['Alexander M. Rush', 'Guillaume Klein', 'Jean Senellart', 'Vincent Nguyen', 'Yoon Kim', 'Yuntian Deng']
# {'Guillaume Klein': 1, 'Yoon Kim': 2, 'Yuntian Deng': 3, 'Vincent Nguyen': 4, 'Jean Senellart': 5, 'Alexander M. Rush': 6}
# -1
#                 name  sequence  star  corre  paperCount  citationCount  \
# 0    Guillaume Klein         1     0      0           5             84
# 1           Yoon Kim         2     0      0          16           1512
# 2       Yuntian Deng         3     0      0           8             76
# 3     Vincent Nguyen         4     0      0           2              0
# 4     Jean Senellart         5     0      0          27            360
# 5  Alexander M. Rush         6     0      0          -1             -1
#
#   authorID
# 0   A49642
# 1  A158099
# 2  A160518
# 3  A146357
# 4   A63045
# 5   A05750
#                    Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Guillaume Klein         1.000000                0.116667     0.078447
# Yoon Kim                0.500000                0.383333     0.373454
# Yuntian Deng            0.333333                0.450000     0.119765
# Vincent Nguyen          0.250000                0.566667     0.028070
# Jean Senellart          0.200000                0.858333     0.414398
# Alexander M. Rush       0.166667                0.900000    -0.014134
#
#                    Resource  Software
# name
# Guillaume Klein       0.250       0.0
# Yoon Kim              0.750       0.0
# Yuntian Deng          0.250       0.0
# Vincent Nguyen        0.000       0.0
# Jean Senellart        0.625       0.0
# Alexander M. Rush     0.000       0.0
# P1159160 http://arxiv.org/pdf/1504.08362v4.pdf
# ['Aijan Ibraimova', 'Dmitry Vetrov', 'Michael Figurnov', 'Pushmeet Kohli']
# {'Michael Figurnov': 1, 'Aijan Ibraimova': 2, 'Dmitry Vetrov': 3, 'Pushmeet Kohli': 4}
# -1
#                name  sequence  star  corre  paperCount  citationCount authorID
# 0  Michael Figurnov         1     0      0           5             36   A95397
# 1   Aijan Ibraimova         2     0      0          -1             -1   A03365
# 2     Dmitry Vetrov         3     0      0          71            501   A35503
# 3    Pushmeet Kohli         4     0      0         272          10721  A113687
#                   Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Michael Figurnov       1.000000                   0.175     0.012167
# Aijan Ibraimova        0.500000                   0.400    -0.002323
# Dmitry Vetrov          0.333333                   0.800     0.172590
# Pushmeet Kohli         0.250000                   1.200     0.817566
#
#                   Resource  Software
# name
# Michael Figurnov     0.125       0.0
# Aijan Ibraimova      0.000       0.0
# Dmitry Vetrov        0.750       0.0
# Pushmeet Kohli       1.500       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1159253 http://arxiv.org/pdf/1808.03912v1.pdf
# ['Feng Tian', 'Jinhui Tang', 'Tat-Seng Chua', 'Xiang Wang', 'Xiangnan He', 'Xiaoyu Du']
# {'Xiangnan He': 1, 'Xiaoyu Du': 2, 'Xiang Wang': 3, 'Feng Tian': 4, 'Jinhui Tang': 5}
# -1
#           name  sequence  star  corre  paperCount  citationCount authorID
# 0  Xiangnan He         1     0      0          60            783  A150860
# 1    Xiaoyu Du         2     0      0           3              1  A152062
# 2   Xiang Wang         3     0      0          16             65  A150769
# 3    Feng Tian         4     0      0          65            503   A43168
# 4  Jinhui Tang         5     0      0          46           2478   A67211
#              Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Xiangnan He       1.000000                   0.250     0.293519     0.750
# Xiaoyu Du         0.500000                   0.300     0.012684     0.000
# Xiang Wang        0.333333                   0.575     0.070763     0.375
# Feng Tian         0.250000                   0.850     0.299951     0.750
# Jinhui Tang       0.200000                   1.050     0.323084     0.750
#
#              Software
# name
# Xiangnan He       0.0
# Xiaoyu Du         0.0
# Xiang Wang        0.0
# Feng Tian         0.0
# Jinhui Tang       0.0
# NAIVE MATCHING
# P1159313 http://arxiv.org/pdf/1708.02863v1.pdf
# ['Chaoyang Zhao', 'Hanqing Lu', 'Jinqiao Wang', 'Xu Zhao', 'Yi Wu', 'Yousong Zhu']
# {'Yousong Zhu': 1, 'Chaoyang Zhao': 2, 'Jinqiao Wang': 3, 'Xu Zhao': 4, 'Yi Wu': 5, 'Hanqing Lu': 6}
# -1
#             name  sequence  star  corre  paperCount  citationCount authorID
# 0    Yousong Zhu         1     0      0           5             17  A158555
# 1  Chaoyang Zhao         2     0      0          19             99   A23423
# 2   Jinqiao Wang         3     0      0         178           1084   A67335
# 3        Xu Zhao         4     0      0          46            333  A153209
# 4          Yi Wu         5     0      0          12             25  A155991
# 5     Hanqing Lu         6     0      0           1              3   A52016
#                Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Yousong Zhu         1.000000                0.091667     0.017504     0.125
# Chaoyang Zhao       0.500000                0.308333     0.070922     0.375
# Jinqiao Wang        0.333333                0.600000     0.684479     1.000
# Xu Zhao             0.250000                0.691667     0.183661     0.625
# Yi Wu               0.200000                0.783333     0.039985     0.250
# Hanqing Lu          0.166667                0.900000     0.003450     0.000
#
#                Software
# name
# Yousong Zhu         0.0
# Chaoyang Zhao       0.0
# Jinqiao Wang        0.0
# Xu Zhao             0.0
# Yi Wu               0.0
# Hanqing Lu          0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1159329 http://arxiv.org/pdf/1804.03675v1.pdf
# ['Baris Gecer', 'Binod Bhattarai', 'Josef Kittler', 'Tae-Kyun Kim']
# {'Baris Gecer': 1, 'Binod Bhattarai': 2, 'Josef Kittler': 3}
# -1
#               name  sequence  star  corre  paperCount  citationCount authorID
# 0      Baris Gecer         1     0      0           4             10   A16752
# 1  Binod Bhattarai         2     0      0           1            140   A18954
# 2    Josef Kittler         3     0      0         769          30111   A70585
#                  Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Baris Gecer           1.000000                0.233333     0.004200     0.000
# Binod Bhattarai       0.500000                0.641667     0.001959     0.375
# Josef Kittler         0.333333                1.200000     0.993841     1.500
#
#                  Software
# name
# Baris Gecer           0.0
# Binod Bhattarai       0.0
# Josef Kittler         0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1159462 http://arxiv.org/pdf/1712.04086v3.pdf
# ['Ashish Khetan', 'Giulia Fanti', 'Sewoong Oh', 'Zinan Lin']
# {'Zinan Lin': 1, 'Ashish Khetan': 2, 'Giulia Fanti': 3, 'Sewoong Oh': 4}
# -1
#             name  sequence  star  corre  paperCount  citationCount authorID
# 0      Zinan Lin         1     0      1           1              0  A164652
# 1  Ashish Khetan         2     0      1          13             39   A14689
# 2   Giulia Fanti         3     0      0          29            194   A48169
# 3     Sewoong Oh         4     0      0          89           2348  A127627
#                Writing_Draft  Writing_Review_Editing  Supervision  Resource  \
# name
# Zinan Lin           1.000000                   1.150     0.006061     0.000
# Ashish Khetan       0.500000                   1.450     0.081810     0.250
# Giulia Fanti        0.333333                   0.750     0.190791     0.500
# Sewoong Oh          0.250000                   1.075     0.721339     0.875
#
#                Software
# name
# Zinan Lin           0.0
# Ashish Khetan       0.0
# Giulia Fanti        0.0
# Sewoong Oh          0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1159471 http://arxiv.org/pdf/1505.06389v3.pdf
# ['Mojtaba Seyedhosseini', 'Ting Liu', 'Tolga Tasdizen']
# {'Ting Liu': 1, 'Mojtaba Seyedhosseini': 2, 'Tolga Tasdizen': 3}
# -1
#                     name  sequence  star  corre  paperCount  citationCount  \
# 0               Ting Liu         1     0      0          20            119
# 1  Mojtaba Seyedhosseini         2     0      0          22            258
# 2         Tolga Tasdizen         3     0      0         139           2855
#
#   authorID
# 0  A141642
# 1   A99827
# 2  A142121
#                        Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Ting Liu                    1.000000                0.333333     0.095762
# Mojtaba Seyedhosseini       0.500000                0.691667     0.113203
# Tolga Tasdizen              0.333333                1.100000     0.791035
#
#                        Resource  Software
# name
# Ting Liu                  0.500       0.0
# Mojtaba Seyedhosseini     0.625       0.0
# Tolga Tasdizen            1.000       0.0
# P1159580 http://arxiv.org/pdf/1709.01894v1.pdf
# ['Carl Edward Rasmussen', 'James Hensman', 'Mark van der Wilk']
# P1159799 http://arxiv.org/pdf/1712.02560v4.pdf
# ['Kohei Watanabe', 'Kuniaki Saito', 'Tatsuya Harada', 'Yoshitaka Ushiku']
# {'Kuniaki Saito': 1, 'Kohei Watanabe': 2, 'Yoshitaka Ushiku': 3, 'Tatsuya Harada': 4}
# -1
#                name  sequence  star  corre  paperCount  citationCount authorID
# 0     Kuniaki Saito         1     0      0          26            150   A79258
# 1    Kohei Watanabe         2     0      0           4              4   A78082
# 2  Yoshitaka Ushiku         3     0      0          33            166  A158243
# 3    Tatsuya Harada         4     0      0         146           1114  A138869
#                   Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Kuniaki Saito          1.000000                    0.25     0.120442
# Kohei Watanabe         0.500000                    0.40     0.015869
# Yoshitaka Ushiku       0.333333                    0.75     0.149468
# Tatsuya Harada         0.250000                    1.10     0.714221
#
#                   Resource  Software
# name
# Kuniaki Saito          0.5       0.0
# Kohei Watanabe         0.0       0.0
# Yoshitaka Ushiku       0.5       0.0
# Tatsuya Harada         1.0       0.0
# P1159914 http://arxiv.org/pdf/1511.08099v1.pdf
# ['Heriberto Cuayáhuitl', 'Oliver Lemon', 'Simon Keizer']
# {'Heriberto Cuayáhuitl': 1, 'Simon Keizer': 2, 'Oliver Lemon': 3}
# -1
#                    name  sequence  star  corre  paperCount  citationCount  \
# 0  Heriberto Cuayáhuitl         1     0      0          -1             -1
# 1          Simon Keizer         2     0      0          52            996
# 2          Oliver Lemon         3     0      0         246           3208
#
#   authorID
# 0   A54176
# 1  A131858
# 2  A106431
#                       Writing_Draft  Writing_Review_Editing  Supervision  \
# name
# Heriberto Cuayáhuitl       1.000000                0.233333    -0.002741
# Simon Keizer               0.500000                0.716667     0.187462
# Oliver Lemon               0.333333                1.150000     0.815279
#
#                       Resource  Software
# name
# Heriberto Cuayáhuitl      0.00       0.0
# Simon Keizer              0.75       0.0
# Oliver Lemon              1.25       0.0
# ORDER MATCHING
# NAIVE MATCHING
# P1160483 https://www.aclweb.org/anthology/D17-1282.pdf
# ['Ju-Chieh Chou', 'Peng-Hsuan Li', 'Ruo-Ping Dong', 'Wei-Yun Ma', 'Yu-Siang Wang']
# {}
# -1
# Empty DataFrame
# Columns: [name, sequence, star, corre, paperCount, citationCount, authorID]
# Index: []
# Empty DataFrame
# Columns: [Writing_Draft, Writing_Review_Editing, Supervision, Resource, Software]
# Index: []
# P1160494 http://arxiv.org/pdf/1706.09569v2.pdf
# ['Ehsan Zare Borzeshi', 'Inigo Jauregi Unanue', 'Massimo Piccardi']
# {'Inigo Jauregi Unanue': 1, 'Ehsan Zare Borzeshi': 2, 'Massimo Piccardi': 3}
# -1
#                    name  sequence  star  corre  paperCount  citationCount  \
# 0  Inigo Jauregi Unanue         1     0      0           3              5
# 1   Ehsan Zare Borzeshi         2     0      0          17             63
# ...
#
# <http://www.scoaring.com/ontology#A81118> ns1:mbox "huanglei@nlsde.buaa.edu.cn" .
#
# <http://www.scoaring.com/ontology#A81119> ns1:mbox "leiji@microsoft.com" .
#
# <http://www.scoaring.com/ontology#A81151> ns1:mbox "tianyu0421@pku.edu.cn" .
#
# <http://www.scoaring.com/ontology#A81173> ns1:mbox "bamos@cs.cmu.edu" .
#
# <http://www.scoaring.com/ontology#A81183> ns1:mbox "1anwangpeng@gmail.com",
#         "cswmzuo@gmail.com" .
#
# <http://www.scoaring.com/ontology#A81202> ns1:mbox "mans.magnusson@liu.se" .
#
# <http://www.scoaring.com/ontology#A81425> ns1:mbox "leon.sixt@fu-berlin.de" .
#
# <http://www.scoaring.com/ontology#A81561> ns1:mbox "leo@boytsov.info" .
#
# <http://www.scoaring.com/ontology#A81590> ns1:mbox "optas@cs.stanford.edu" .
#
# <http://www.scoaring.com/ontology#A81646> ns1:mbox "ziw@csail.mit.edu" .
#
# <http://www.scoaring.com/ontology#A81669> ns1:mbox " letao.qi@rice.edu" .
#
# <http://www.scoaring.com/ontology#A81748> ns1:mbox "first.last@anu.edu.au" .
#
# <http://www.scoaring.com/ontology#A81798> ns1:mbox "" .
#
# <http://www.scoaring.com/ontology#A81804> ns1:mbox "shuye.ys@gmail.com" .
#
# <http://www.scoaring.com/ontology#A81889> ns1:mbox "david.lizhang@qmul.ac.uk" .
#
# <http://www.scoaring.com/ontology#A82026> ns1:mbox "liang.huang.sh@gmail.com" .
#
# <http://www.scoaring.com/ontology#A82033> ns1:mbox "linliang@ieee.org" .
#
# <http://www.scoaring.com/ontology#A82070> ns1:mbox "liangzhang@xidian.edu.cn" .
#
# <http://www.scoaring.com/ontology#A82133> ns1:mbox "liangliang@yahoo-inc.com" .
#
# <http://www.scoaring.com/ontology#A82268> ns1:mbox "lidan.wang@rutgers.edu" .
#
# <http://www.scoaring.com/ontology#A82310> ns1:mbox "lifanghescut@gmail.com" .
#
# <http://www.scoaring.com/ontology#A82372> ns1:mbox "lihongli@microsoft.com" .
#
# <http://www.scoaring.com/ontology#A82374> ns1:mbox "" .
#
# <http://www.scoaring.com/ontology#A82465> ns1:mbox "hpallika@uwaterloo.ca" .
#
# <http://www.scoaring.com/ontology#A82509> ns1:mbox "fredrik.jorgensen@schibsted.com" .
#
# <http://www.scoaring.com/ontology#A82544> ns1:mbox "07wanglimin@gmail.com",
#         "bitxiong@gmail.com",
#         "wangzhe2012@gmail.com" .
#
# <http://www.scoaring.com/ontology#A82597> ns1:mbox "linmawhu@gmail.com" .
#
# <http://www.scoaring.com/ontology#A82598> ns1:mbox "gmzhu@xidian.edu.cn" .
#
# <http://www.scoaring.com/ontology#A82723> ns1:mbox " caspian@cs.washington.edu" .
#
# <http://www.scoaring.com/ontology#A82830> ns1:mbox "ianyen@cs.utexas.edu" .
#
# <http://www.scoaring.com/ontology#A82836> ns1:mbox "jianlong.chang@nlpr.ia.ac.cn" .
#
# <http://www.scoaring.com/ontology#A82887> ns1:mbox "jie.yang01@adelaide.edu.au" .
#
# <http://www.scoaring.com/ontology#A82995> ns1:mbox "linjie.yang@snap.com" .
#
# <http://www.scoaring.com/ontology#A83172> ns1:mbox "nieliqiang@gmail.com" .
#
# <http://www.scoaring.com/ontology#A83234> ns1:mbox "lbauer6@cs.unc.edu" .
#
# <http://www.scoaring.com/ontology#A83255> ns1:mbox "stephan.tulkens@uantwerpen.be" .
#
# <http://www.scoaring.com/ontology#A83368> ns1:mbox "ostroumova-la@yandex-team.ru" .
#
# <http://www.scoaring.com/ontology#A83422> ns1:mbox "luotg@pku.edu.cn" .
#
# <http://www.scoaring.com/ontology#A83470> ns1:mbox "liyanc@uci.edu" .
#
# <http://www.scoaring.com/ontology#A83529> ns1:mbox "dat.nguyen@students.mq.edu.au" .
#
# <http://www.scoaring.com/ontology#A83679> ns1:mbox "mtlong@cs.pdx.edu" .
#
# <http://www.scoaring.com/ontology#A83705> ns1:mbox "yt219@cs.rutgers.edu" .
#
# <http://www.scoaring.com/ontology#A83745> ns1:mbox "ly283@cornell.edu" .
#
# <http://www.scoaring.com/ontology#A83786> ns1:mbox "c.m.van.son@vu.nl" .
#
# <http://www.scoaring.com/ontology#A83878> ns1:mbox "alessandro.rudi@inria.fr" .
#
# <http://www.scoaring.com/ontology#A84118> ns1:mbox "lsheng@ee.cuhk.edu.hk" .
#
# <http://www.scoaring.com/ontology#A84135> ns1:mbox "luyuan@microsoft.com" .
#
# <http://www.scoaring.com/ontology#A84203> ns1:mbox "andrey.ignatoff@gmail.com" .
#
# <http://www.scoaring.com/ontology#A84276> ns1:mbox "luca.franceschi@iit.it" .
#
# <http://www.scoaring.com/ontology#A84338> ns1:mbox "denis.gudovskiy@us.panasonic.com" .
#
# <http://www.scoaring.com/ontology#A84345> ns1:mbox "frcasale@microsoft.com" .
#
# <http://www.scoaring.com/ontology#A84493> ns1:mbox "liuluchen@pku.edu.cn" .
#
# <http://www.scoaring.com/ontology#A84512> ns1:mbox "julia.ive@kcl.ac.uk" .
#
# <http://www.scoaring.com/ontology#A84647> ns1:mbox "mickael.chen@lip6.fr" .
#
# <http://www.scoaring.com/ontology#A84662> ns1:mbox "ludovic.trottier.1@ulaval.ca" .
#
# <http://www.scoaring.com/ontology#A84682> ns1:mbox "ludwigs@mit.edu" .
#
# <http://www.scoaring.com/ontology#A84691> ns1:mbox "luheng@cs.washington.edu" .
#
# <http://www.scoaring.com/ontology#A84701> ns1:mbox "alessandro.rudi@inria.fr" .
#
# <http://www.scoaring.com/ontology#A84826> ns1:mbox " lherranz@cvc.uab.es" .
#
# <http://www.scoaring.com/ontology#A85019> ns1:mbox "marios.anthimopoulos@artorg.unibe.ch" .
#
# <http://www.scoaring.com/ontology#A85031> ns1:mbox "l.galke@zbw.eu" .
#
# <http://www.scoaring.com/ontology#A85203> ns1:mbox " kentonl@cs.washington.edu",
#         " luheng@cs.washington.edu" .
#
# <http://www.scoaring.com/ontology#A85274> ns1:mbox "luozhou@umich.edu" .
#
# <http://www.scoaring.com/ontology#A85406> ns1:mbox "xh@cis.upenn.edu" .
#
# <http://www.scoaring.com/ontology#A85909> ns1:mbox "pawan@robots.ox.ac.uk" .
#
# <http://www.scoaring.com/ontology#A86235> ns1:mbox "Gregory.Kucherov@u-pem.fr" .
#
# <http://www.scoaring.com/ontology#A86286> ns1:mbox "udell@stanford.edu" .
#
# <http://www.scoaring.com/ontology#A86396> ns1:mbox "Jason.Ramapuram@etu.unige.ch" .
#
# <http://www.scoaring.com/ontology#A86444> ns1:mbox "rstname.lastname@tomologic.com" .
#
# <http://www.scoaring.com/ontology#A86789> ns1:mbox "maixu@buaa.edu.cn" .
#
# <http://www.scoaring.com/ontology#A86846> ns1:mbox "marc.bolanos@ub.edu" .
#
# <http://www.scoaring.com/ontology#A86854> ns1:mbox "maithrar@gmail.com" .
#
# <http://www.scoaring.com/ontology#A86872> ns1:mbox "maja@cs.columbia.edu" .
#
# <http://www.scoaring.com/ontology#A87327> ns1:mbox " dmanik@cs.stanford.edu" .
#
# <http://www.scoaring.com/ontology#A87354> ns1:mbox "gmanish@microsoft.com" .
#
# <http://www.scoaring.com/ontology#A87374> ns1:mbox "manik@microsoft.com" .
#
# <http://www.scoaring.com/ontology#A87476> ns1:mbox "manon.kok@liu.se" .
#
# <http://www.scoaring.com/ontology#A87540> ns1:mbox "mantas@ttic.edu" .
#
# <http://www.scoaring.com/ontology#A87570> ns1:mbox "ﬁrstname}.{lastname@unifr.ch" .
#
# <http://www.scoaring.com/ontology#A87726> ns1:mbox "cgirardi | manspera | sprugnoli | satonelli@fbk.eu" .
#
# <http://www.scoaring.com/ontology#A87743> ns1:mbox "shamsi.saqib@gmail.com" .
#
# <http://www.scoaring.com/ontology#A87748> ns1:mbox "manzilz@cs.cmu.edu" .
#
# <http://www.scoaring.com/ontology#A87790> ns1:mbox "hzk14@mails.tsinghua.edu.cn",
#         "liuzy@tsinghua.edu.cn",
#         "uzy@tsinghua.edu.cn" .
#
# <http://www.scoaring.com/ontology#A87832> ns1:mbox "marc.bolanos@ub.edu" .
#
# <http://www.scoaring.com/ontology#A87911> ns1:mbox "alexandre.hollocou@inria.fr" .
#
# <http://www.scoaring.com/ontology#A87935> ns1:mbox "chofer@cosy.sbg.ac.at" .
#
# <http://www.scoaring.com/ontology#A88041> ns1:mbox "y.gucluturk@donders.ru.nl" .
#
# <http://www.scoaring.com/ontology#A88223> ns1:mbox "marcin.moczulski@stcatz.ox.ac.uk" .
#
# <http://www.scoaring.com/ontology#A88239> ns1:mbox "sam.kriegman@uvm.edu" .
#
# <http://www.scoaring.com/ontology#A88634> ns1:mbox "marcus.bloice@medunigraz.at" .
#
# <http://www.scoaring.com/ontology#A88644> ns1:mbox "john.aslanides@anu.edu.au" .
#
# <http://www.scoaring.com/ontology#A88652> ns1:mbox "ﬁrstname}.{lastname@unifr.ch" .
#
# <http://www.scoaring.com/ontology#A88797> ns1:mbox "margo@eecs.harvard.edu" .
#
# <http://www.scoaring.com/ontology#A89198> ns1:mbox "FirstName.LastName@imag.fr" .
#
# <http://www.scoaring.com/ontology#A89285> ns1:mbox "marie.candito@linguist.univ-paris-diderot.fr" .
#
# <http://www.scoaring.com/ontology#A89307> ns1:mbox "vangool@vision.ee.ethz.ch" .
#
# <http://www.scoaring.com/ontology#A89352> ns1:mbox "marc.bolanos@ub.edu" .
#
# <http://www.scoaring.com/ontology#A89548> ns1:mbox "m.weiler@uva.nl" .
#
# <http://www.scoaring.com/ontology#A89625> ns1:mbox "garnett@wustl.edu" .
#
# <http://www.scoaring.com/ontology#A89638> ns1:mbox "marios.anthimopoulos@artorg.unibe.ch" .
#
# <http://www.scoaring.com/ontology#A89870> ns1:mbox "dat.nguyen@mq.edu.au",
#         "dat.nguyen@students.mq.edu.au" .
#
# <http://www.scoaring.com/ontology#A89893> ns1:mbox "faez00@umd.edu" .
#
# <http://www.scoaring.com/ontology#A89950> ns1:mbox "dat.nguyen@mq.edu.au",
#         "dat.nguyen@students.mq.edu.au" .
#
# <http://www.scoaring.com/ontology#A90054> ns1:mbox "keunwoo.choi@qmul.ac.uk" .
#
# <http://www.scoaring.com/ontology#A90114> ns1:mbox "yg279@cam.ac.uk" .
#
# <http://www.scoaring.com/ontology#A90186> ns1:mbox "tobias.gruening@uni-rostock.de" .
#
# <http://www.scoaring.com/ontology#A90276> ns1:mbox "robin.ruede@student.kit.edu" .
#
# <http://www.scoaring.com/ontology#A90414> ns1:mbox "wenjie.ruan; marta.kwiatkowska@cs.ox.ac.uk" .
#
# <http://www.scoaring.com/ontology#A90563> ns1:mbox "martin@occamzrazor.com" .
#
# <http://www.scoaring.com/ontology#A90572> ns1:mbox "rstname.lastname@tomologic.com" .
#
# <http://www.scoaring.com/ontology#A90688> ns1:mbox "senthil.yogamani@valeo.com" .
#
# <http://www.scoaring.com/ontology#A90968> ns1:mbox "kahng | polo@gatech.edu" .
#
# <http://www.scoaring.com/ontology#A91406> ns1:mbox "ichi@sys.i.kyoto-u.ac.jp" .
#
# <http://www.scoaring.com/ontology#A91438> ns1:mbox "phi.thuy.ph8@is.naist.jp" .
#
# <http://www.scoaring.com/ontology#A91439> ns1:mbox "voot.tangkaratt@riken.jp" .
#
# <http://www.scoaring.com/ontology#A91626> ns1:mbox "luca.franceschi@iit.it" .
#
# <http://www.scoaring.com/ontology#A91656> ns1:mbox "rcha9612@uni.sydney.edu.au" .
#
# <http://www.scoaring.com/ontology#A91711> ns1:mbox "rst.last@gmail.com" .
#
# <http://www.scoaring.com/ontology#A91718> ns1:mbox "alan.lukezic@fri.uni-lj.si" .
#
# <http://www.scoaring.com/ontology#A91904> ns1:mbox "MATHIEU.GERMAIN2@USHERBROOKE.CA" .
#
# <http://www.scoaring.com/ontology#A92013> ns1:mbox "matin@sharif.edu" .
#
# <http://www.scoaring.com/ontology#A92284> ns1:mbox "wacha.bounliphone@inria.fr" .
#
# <http://www.scoaring.com/ontology#A92296> ns1:mbox "WACHA.BOUNLIPHONE@CENTRALESUPELEC.FR" .
#
# <http://www.scoaring.com/ontology#A92595> ns1:mbox "kk7nc@virginia.edu" .
#
# <http://www.scoaring.com/ontology#A92623> ns1:mbox "mstaib@mit.edu" .
#
# <http://www.scoaring.com/ontology#A92700> ns1:mbox "alexander.ecker@uni-tuebingen.de",
#         "robert.geirhos@bethgelab.org" .
#
# <http://www.scoaring.com/ontology#A92704> ns1:mbox "matthias@datastax.com" .
#
# <http://www.scoaring.com/ontology#A92912> ns1:mbox "hedi.ben-younes@lip6.fr",
#         "micael.carvalho@lip6.fr" .
#
# <http://www.scoaring.com/ontology#A92914> ns1:mbox "MATTHIEU.COURBARIAUX@GMAIL.COM",
#         "matthieu.courbariaux@polymtl.ca" .
#
# <http://www.scoaring.com/ontology#A92953> ns1:mbox "matthijs@fb.com" .
#
# <http://www.scoaring.com/ontology#A93024> ns1:mbox "ksmith@kth.se" .
#
# <http://www.scoaring.com/ontology#A93118> ns1:mbox "m.weiler@uva.nl" .
#
# <http://www.scoaring.com/ontology#A93238> ns1:mbox "mausam@cse.iitd.ac.in" .
#
# <http://www.scoaring.com/ontology#A93354> ns1:mbox "dkm@cs.cornell.edu" .
#
# <http://www.scoaring.com/ontology#A93368> ns1:mbox "e.hoogeboom@uva.nl",
#         "m.weiler@uva.nl" .
#
# <http://www.scoaring.com/ontology#A93499> ns1:mbox "e.j.bekkers@tue.nl" .
#
# <http://www.scoaring.com/ontology#A93613> ns1:mbox "ranzhao1@cs.cmu.edu" .
#
# <http://www.scoaring.com/ontology#A93651> ns1:mbox "mayagupta@google.com" .
#
# <http://www.scoaring.com/ontology#A93750> ns1:mbox "maziarsanjabi@gmail.com" .
#
# <http://www.scoaring.com/ontology#A94074> ns1:mbox "mehdi.b.tn@gmail.com" .
#
# <http://www.scoaring.com/ontology#A94093> ns1:mbox "harm.vanseijen@microsoft.com" .
#
# <http://www.scoaring.com/ontology#A94115> ns1:mbox "mehdih@cs.rochester.edu" .
#
# <http://www.scoaring.com/ontology#A94222> ns1:mbox "mehran@sci.utah.edu" .
#
# <http://www.scoaring.com/ontology#A94581> ns1:mbox "2jialu@google.com" .
#
# <http://www.scoaring.com/ontology#A94599> ns1:mbox "xren7@illinois.edu" .
#
# <http://www.scoaring.com/ontology#A94647> ns1:mbox "fengmengdan@u.nus.edu" .
#
# <http://www.scoaring.com/ontology#A94723> ns1:mbox "mengmi@u.nus.edu" .
#
# <http://www.scoaring.com/ontology#A94783> ns1:mbox "mengyangfeng@gmail.com" .
#
# <http://www.scoaring.com/ontology#A94839> ns1:mbox "mennatul@ualberta.ca" .
#
# <http://www.scoaring.com/ontology#A94948> ns1:mbox " mozay@vision.is.tohoku.ac.jp" .
#
# <http://www.scoaring.com/ontology#A95047> ns1:mbox "csmiaozhao@comp.polyu.edu.hk" .
#
# <http://www.scoaring.com/ontology#A95066> ns1:mbox "micael.carvalho@lip6.fr" .
#
# <http://www.scoaring.com/ontology#A95143> ns1:mbox "michael.n.arbel@gmail.com" .
#
# <http://www.scoaring.com/ontology#A95286> ns1:mbox "ram21@vt.edu" .
#
# <http://www.scoaring.com/ontology#A95314> ns1:mbox "1bridgesra@ornl.gov" .
#
# <http://www.scoaring.com/ontology#A95397> ns1:mbox "michael@figurnov.ru" .
#
# <http://www.scoaring.com/ontology#A95446> ns1:mbox "michaelg@ucf.edu" .
#
# <http://www.scoaring.com/ontology#A95695> ns1:mbox "" .
#
# <http://www.scoaring.com/ontology#A95983> ns1:mbox "moussallem@informatik.uni-leipzig.de" .
#
# <http://www.scoaring.com/ontology#A96140> ns1:mbox "michaelt@nari.ee.ethz.ch" .
#
# <http://www.scoaring.com/ontology#A96200> ns1:mbox "" .
#
# <http://www.scoaring.com/ontology#A96291> ns1:mbox "michal@imagia.com" .
#
# <http://www.scoaring.com/ontology#A96439> ns1:mbox "name.surname@put.poznan.pl" .
#
# <http://www.scoaring.com/ontology#A96557> ns1:mbox "ﬁrstname}.{lastname@unifr.ch" .
#
# <http://www.scoaring.com/ontology#A96582> ns1:mbox "luca.franceschi@iit.it" .
#
# <http://www.scoaring.com/ontology#A96729> ns1:mbox "OLIVIER.GOUDET@INRIA.FR" .
#
# <http://www.scoaring.com/ontology#A96739> ns1:mbox "mickael.chen@lip6.fr" .
#
# <http://www.scoaring.com/ontology#A96798> ns1:mbox "miguel.ballesteros@upf.edu" .
#
# <http://www.scoaring.com/ontology#A97058> ns1:mbox "rstname.lastname@tomologic.com" .
#
# <http://www.scoaring.com/ontology#A97110> ns1:mbox " mikelewis@fb.com",
#         "mikelewis@fb.com" .
#
# <http://www.scoaring.com/ontology#A97154> ns1:mbox "mike@michaelchughes.com" .
#
# <http://www.scoaring.com/ontology#A97158> ns1:mbox "mikel.artetxe@ehu.eus" .
#
# <http://www.scoaring.com/ontology#A97250> ns1:mbox "keskar.nitish@u.northwestern.edu" .
#
# <http://www.scoaring.com/ontology#A97290> ns1:mbox "mthorup@di.ku.dk" .
#
# <http://www.scoaring.com/ontology#A97317> ns1:mbox "mikbinkowski@gmail.com" .
#
# <http://www.scoaring.com/ontology#A97552> ns1:mbox "qiang@siat.ac.cn" .
#
# <http://www.scoaring.com/ontology#A97701> ns1:mbox "Zhao.Kang@siu.edu",
#         "mingyang@sjtu.edu.cn" .
#
# <http://www.scoaring.com/ontology#A97712> ns1:mbox "mingzhou@microsoft.com" .
#
# <http://www.scoaring.com/ontology#A97907> ns1:mbox "chaohui.wang@u-pem.fr" .
#
# <http://www.scoaring.com/ontology#A97948> ns1:mbox "mingsheng@tsinghua.edu.cn" .
#
# <http://www.scoaring.com/ontology#A98038> ns1:mbox "zhangguofeng@cad.zju.edu.cn" .
#
# <http://www.scoaring.com/ontology#A98132> ns1:mbox "craffel@gmail.com" .
#
# <http://www.scoaring.com/ontology#A98199> ns1:mbox "youngjin.kim@vision.snu.ac.kr" .
#
# <http://www.scoaring.com/ontology#A98273> ns1:mbox "kahng | polo@gatech.edu" .
#
# <http://www.scoaring.com/ontology#A98399> ns1:mbox "x.zhang@ed.ac.uk" .
#
# <http://www.scoaring.com/ontology#A98584> ns1:mbox "xh@cis.upenn.edu" .
#
# <http://www.scoaring.com/ontology#A98616> ns1:mbox "e.j.bekkers@tue.nl" .
#
# <http://www.scoaring.com/ontology#A98717> ns1:mbox "senthil.yogamani@valeo.com" .
#
# <http://www.scoaring.com/ontology#A99145> ns1:mbox "" .
#
# <http://www.scoaring.com/ontology#A99256> ns1:mbox "r.clegg@qmul.ac.uk" .
#
# <http://www.scoaring.com/ontology#A99312> ns1:mbox "mohammadr@allenai.org" .
#
# <http://www.scoaring.com/ontology#A99521> ns1:mbox "robert.hoehndorf@kaust.edu.sa" .
#
# <http://www.scoaring.com/ontology#A99673> ns1:mbox "lbauer6@cs.unc.edu" .
#
# <http://www.scoaring.com/ontology#A99685> ns1:mbox "paolo.dragone@unitn.it" .
#
# <http://www.scoaring.com/ontology#A99807> ns1:mbox "kk7nc@virginia.edu" .
#
# <http://www.scoaring.com/ontology#A99867> ns1:mbox "robert.hoehndorf@kaust.edu.sa" .
#
# <http://www.scoaring.com/ontology#A99941> ns1:mbox "a.aker@dcs.shef.ac.uk" .
